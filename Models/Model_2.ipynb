# %%
import torch, torchvision
import torchvision.transforms as transforms
import torch.nn as nn, torch.nn.functional as F
import torch.optim as optim, torch.utils.data as data
import torchvision.datasets as datasets
import time, copy, random, os, numpy as np
import matplotlib.pyplot as plt
from torchvision.transforms.autoaugment import AutoAugmentPolicy
from torch.optim.lr_scheduler import ReduceLROnPlateau, OneCycleLR
from torch.utils.data import random_split
from torchsummary import summary

# %%
BATCH_SIZE = 64
INPUT_SIZE = (3, 32, 32)
EPOCHS = 150
LEARNING_RATE = 1e-3

# %%
#Verify GPU
# !nvidia-smi
# Out:
# Mon Apr 10 14:38:18 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    47W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Specify device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Sets the seed for numpy and torch to make sure functions with a random component behave deterministically
# torch.backends.cudnn.deterministic = true sets the CuDNN to deterministic mode.
# This function allows us to run experiments 100% deterministically.
# https://gist.github.com/ihoromi4/b681a9088f348942b01711f251e5f964

def seed_everything(seed=1234):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything()

# %% [markdown]
# # 1.  Load and Batch the Data

# %%
def get_data_loaders(batch_size, root = '.data', valid_ratio = 0.1):
  
    #means and stds for the 3 channels of the dataset
    means = (0.4914, 0.4822, 0.4465)
    stds = (0.2023, 0.1994, 0.2010)

    #   Performs the following data augmentations on the training set:
    #       1.  Random Rotation:  
    #       2.  RandomHorizontalFlip
    #       3.  Random Crop
    #       4.  AutoAugment: AutoAugmention policies learned from the CIFAR10 dataset
    #           AutoAugment: Learning Augmentation Strategies from Data" <https://arxiv.org/pdf/1805.09501.pdf>`
    train_transforms = transforms.Compose([
                           transforms.RandomRotation(5),
                           transforms.RandomHorizontalFlip(0.5),
                           transforms.RandomCrop(32, padding = 2),
                           transforms.AutoAugment(AutoAugmentPolicy.CIFAR10),
                           transforms.ToTensor(),  # convert data to torch.FloatTensor: CxHxW
                           transforms.Normalize(mean = means, std = stds, inplace=True), #Range is in [-1,1], data = (data - mean)/std
                       ])

    test_transforms = transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize(mean = means, std = stds, inplace=True),
                       ])

    # choose the training and test datasets
    train_data = datasets.CIFAR10(root, 
                              train = True, 
                              download = True, 
                              transform = train_transforms)
    
    test_data = datasets.CIFAR10(root, 
                             train = False, 
                             download = True, 
                             transform = test_transforms)
    
    # obtain number of training/validation examples that will be used to create the respective datasets 
    n_train_examples = int((1 - valid_ratio) * len(train_data))
    n_valid_examples = int(valid_ratio* len(train_data))

    train_data, valid_data = random_split(train_data, [n_train_examples, n_valid_examples])
    
    #Creates a deep copy
    valid_data = copy.deepcopy(valid_data)  
    valid_data.dataset.transform = test_transforms

    # load training data in batches
    train_dataloader = data.DataLoader(train_data,
                                 shuffle = True,
                                 batch_size = batch_size,
                                 num_workers=2, 
                                 pin_memory=True)   #pin_memory speeds transfer of data from CPU to GPU

    # load validation data in batches
    valid_dataloader = data.DataLoader(valid_data,
                                 batch_size = batch_size,
                                 num_workers=2, 
                                 pin_memory=True)

    # load test data in batches
    test_dataloader = data.DataLoader(test_data,
                                batch_size = batch_size,
                                num_workers=2, 
                                pin_memory=True)
  
    return train_dataloader, valid_dataloader, test_dataloader

# %%
# Load and batch the data
train_dataloader, valid_dataloader, test_dataloader = get_data_loaders(BATCH_SIZE)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to .data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:13<00:00, 12326446.92it/s]
# Extracting .data/cifar-10-python.tar.gz to .data
# Files already downloaded and verified

# %% [markdown]
# # 2.  Define the Network

# %%
'''ResNet in PyTorch.
For Pre-activation ResNet, see 'preact_resnet.py'.
Reference:
[1] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun
    Deep Residual Learning for Image Recognition. arXiv:1512.03385
'''

#Residual Block
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=3,padding=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

#1. Convolutional Layer: conv1
#2. Residual Layers: layer1, layer2, layer3, layer4
#3. Fully Connected Layer: linear
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 32

        self.conv1 = nn.Conv2d(3, 32, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        self.layer1 = self._make_layer(block, 32, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 128, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 256, num_blocks[3], stride=2)
        self.linear = nn.Linear(256*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

#ResNet18 has 4 residual layers, each composed of a specifed number of residual blocks
def ResNet18():
    return ResNet(BasicBlock, [10,8,6,2])

# %% [markdown]
# # 3.  Specify Model, Loss Function, Optimizer, and Scheduler

# %%
# Specify the model, loss function, and optimizer; move model to device
model = ResNet18().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# Specify scheduler
scheduler = ReduceLROnPlateau(optimizer, 'min')

# %%
# Check total number of parameters
summary(model, input_size=INPUT_SIZE)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#             Conv2d-3           [-1, 32, 32, 32]           9,216
#        BatchNorm2d-4           [-1, 32, 32, 32]              64
#             Conv2d-5           [-1, 32, 32, 32]           9,216
#        BatchNorm2d-6           [-1, 32, 32, 32]              64
#         BasicBlock-7           [-1, 32, 32, 32]               0
#             Conv2d-8           [-1, 32, 32, 32]           9,216
#        BatchNorm2d-9           [-1, 32, 32, 32]              64
#            Conv2d-10           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-11           [-1, 32, 32, 32]              64
#        BasicBlock-12           [-1, 32, 32, 32]               0
#            Conv2d-13           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-14           [-1, 32, 32, 32]              64
#            Conv2d-15           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-16           [-1, 32, 32, 32]              64
#        BasicBlock-17           [-1, 32, 32, 32]               0
#            Conv2d-18           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-19           [-1, 32, 32, 32]              64
#            Conv2d-20           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-21           [-1, 32, 32, 32]              64
#        BasicBlock-22           [-1, 32, 32, 32]               0
#            Conv2d-23           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-24           [-1, 32, 32, 32]              64
#            Conv2d-25           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-26           [-1, 32, 32, 32]              64
#        BasicBlock-27           [-1, 32, 32, 32]               0
#            Conv2d-28           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-29           [-1, 32, 32, 32]              64
#            Conv2d-30           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-31           [-1, 32, 32, 32]              64
#        BasicBlock-32           [-1, 32, 32, 32]               0
#            Conv2d-33           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-34           [-1, 32, 32, 32]              64
#            Conv2d-35           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-36           [-1, 32, 32, 32]              64
#        BasicBlock-37           [-1, 32, 32, 32]               0
#            Conv2d-38           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-39           [-1, 32, 32, 32]              64
#            Conv2d-40           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-41           [-1, 32, 32, 32]              64
#        BasicBlock-42           [-1, 32, 32, 32]               0
#            Conv2d-43           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-44           [-1, 32, 32, 32]              64
#            Conv2d-45           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-46           [-1, 32, 32, 32]              64
#        BasicBlock-47           [-1, 32, 32, 32]               0
#            Conv2d-48           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-49           [-1, 32, 32, 32]              64
#            Conv2d-50           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-51           [-1, 32, 32, 32]              64
#        BasicBlock-52           [-1, 32, 32, 32]               0
#            Conv2d-53           [-1, 64, 16, 16]          18,432
#       BatchNorm2d-54           [-1, 64, 16, 16]             128
#            Conv2d-55           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-56           [-1, 64, 16, 16]             128
#            Conv2d-57           [-1, 64, 16, 16]          18,432
#       BatchNorm2d-58           [-1, 64, 16, 16]             128
#        BasicBlock-59           [-1, 64, 16, 16]               0
#            Conv2d-60           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-61           [-1, 64, 16, 16]             128
#            Conv2d-62           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-63           [-1, 64, 16, 16]             128
#        BasicBlock-64           [-1, 64, 16, 16]               0
#            Conv2d-65           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-66           [-1, 64, 16, 16]             128
#            Conv2d-67           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-68           [-1, 64, 16, 16]             128
#        BasicBlock-69           [-1, 64, 16, 16]               0
#            Conv2d-70           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-71           [-1, 64, 16, 16]             128
#            Conv2d-72           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-73           [-1, 64, 16, 16]             128
#        BasicBlock-74           [-1, 64, 16, 16]               0
#            Conv2d-75           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-76           [-1, 64, 16, 16]             128
#            Conv2d-77           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-78           [-1, 64, 16, 16]             128
#        BasicBlock-79           [-1, 64, 16, 16]               0
#            Conv2d-80           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-81           [-1, 64, 16, 16]             128
#            Conv2d-82           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-83           [-1, 64, 16, 16]             128
#        BasicBlock-84           [-1, 64, 16, 16]               0
#            Conv2d-85           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-86           [-1, 64, 16, 16]             128
#            Conv2d-87           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-88           [-1, 64, 16, 16]             128
#        BasicBlock-89           [-1, 64, 16, 16]               0
#            Conv2d-90           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-91           [-1, 64, 16, 16]             128
#            Conv2d-92           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-93           [-1, 64, 16, 16]             128
#        BasicBlock-94           [-1, 64, 16, 16]               0
#            Conv2d-95            [-1, 128, 8, 8]          73,728
#       BatchNorm2d-96            [-1, 128, 8, 8]             256
#            Conv2d-97            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-98            [-1, 128, 8, 8]             256
#            Conv2d-99            [-1, 128, 8, 8]          73,728
#      BatchNorm2d-100            [-1, 128, 8, 8]             256
#       BasicBlock-101            [-1, 128, 8, 8]               0
#           Conv2d-102            [-1, 128, 8, 8]         147,456
#      BatchNorm2d-103            [-1, 128, 8, 8]             256
#           Conv2d-104            [-1, 128, 8, 8]         147,456
#      BatchNorm2d-105            [-1, 128, 8, 8]             256
#       BasicBlock-106            [-1, 128, 8, 8]               0
#           Conv2d-107            [-1, 128, 8, 8]         147,456
#      BatchNorm2d-108            [-1, 128, 8, 8]             256
#           Conv2d-109            [-1, 128, 8, 8]         147,456
#      BatchNorm2d-110            [-1, 128, 8, 8]             256
#       BasicBlock-111            [-1, 128, 8, 8]               0
#           Conv2d-112            [-1, 128, 8, 8]         147,456
#      BatchNorm2d-113            [-1, 128, 8, 8]             256
#           Conv2d-114            [-1, 128, 8, 8]         147,456
#      BatchNorm2d-115            [-1, 128, 8, 8]             256
#       BasicBlock-116            [-1, 128, 8, 8]               0
#           Conv2d-117            [-1, 128, 8, 8]         147,456
#      BatchNorm2d-118            [-1, 128, 8, 8]             256
#           Conv2d-119            [-1, 128, 8, 8]         147,456
#      BatchNorm2d-120            [-1, 128, 8, 8]             256
#       BasicBlock-121            [-1, 128, 8, 8]               0
#           Conv2d-122            [-1, 128, 8, 8]         147,456
#      BatchNorm2d-123            [-1, 128, 8, 8]             256
#           Conv2d-124            [-1, 128, 8, 8]         147,456
#      BatchNorm2d-125            [-1, 128, 8, 8]             256
#       BasicBlock-126            [-1, 128, 8, 8]               0
#           Conv2d-127            [-1, 256, 4, 4]         294,912
#      BatchNorm2d-128            [-1, 256, 4, 4]             512
#           Conv2d-129            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-130            [-1, 256, 4, 4]             512
#           Conv2d-131            [-1, 256, 4, 4]         294,912
#      BatchNorm2d-132            [-1, 256, 4, 4]             512
#       BasicBlock-133            [-1, 256, 4, 4]               0
#           Conv2d-134            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-135            [-1, 256, 4, 4]             512
#           Conv2d-136            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-137            [-1, 256, 4, 4]             512
#       BasicBlock-138            [-1, 256, 4, 4]               0
#           Linear-139                   [-1, 10]           2,570
# ================================================================
# Total params: 4,915,754
# Trainable params: 4,915,754
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 20.63
# Params size (MB): 18.75
# Estimated Total Size (MB): 39.39
# ----------------------------------------------------------------

# %% [markdown]
# #4. Training and Validation

# %%
# accuracy is the fraction of predictions the model got correct
def calculate_accuracy(y_pred, y):
    top_pred = y_pred.argmax(1, keepdim = True)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    acc = correct.float() / y.shape[0]
    return acc

# time interval for each epoch
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
def train(model, iterator, optimizer, criterion, device):
    
    # Tracks training loss and accuracy as model trains
    epoch_loss = 0
    epoch_acc = 0
    #lrs = []

    # Prep model for training
    model.train()

    for (x, y) in iterator:
        # Move inputs and labels to device
        x = x.to(device)
        y = y.to(device)
        
        # Clear the gradients of all optimized variables
        optimizer.zero_grad()

        # Forward pass: compute predicted outputs by passing inputs to the model        
        y_pred = model(x)
        
        # Calculate the loss
        loss = criterion(y_pred, y)
        
        # Calculate the accuracy
        acc = calculate_accuracy(y_pred, y)
        
        # Backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()

        #OneCycleLr Scheduler
        #scheduler.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def evaluate(model, iterator, criterion, device):
    # Keeps track of validation loss and  accuracy
    epoch_loss = 0
    epoch_acc = 0
    
    # Prep model for evaluation
    model.eval()
    
    with torch.no_grad():
        
        for (x, y) in iterator:

            x = x.to(device)
            y = y.to(device)

            # Forward Pass
            y_pred = model(x)
            # Calculate the validation loss
            loss = criterion(y_pred, y)
            #Calculate the validation accuracy
            acc = calculate_accuracy(y_pred, y)

            #Record validation loss
            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
# Train and Validate the model:

# Tracks average training loss and accuracy per epoch
#  and tracks average validation loss and accuracy per epoch
Train_Loss = []
Train_Acc = []
Val_Loss = []
Val_Acc = []


# Tracks best validation loss
best_valid_loss = float('inf')
for epoch in range(EPOCHS):
    # Epoch start time
    start_time = time.monotonic()


    train_loss, train_acc = train(model, train_dataloader, optimizer, criterion, device)
    valid_loss, valid_acc = evaluate(model, valid_dataloader, criterion, device)
  

    # OnReducePlateau is a scheduler monitoring validation loss
    scheduler.step(valid_loss)

    # Saves model with best validation loss in a state dictionary
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(),'Model_2.pt')
    # Epoch end time
    end_time = time.monotonic()

    # Prints training/validation statistics as well as epoch time
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    print(f'Epoch: {epoch+1:02} || EpochTime: {epoch_mins}m{epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} || Train Acc: {train_acc*100:.2f}%')
    print(f'\t Val Loss: {valid_loss:.3f} ||  Val Acc: {valid_acc*100:.2f}%')

    Train_Loss.append(train_loss)
    Train_Acc.append(train_acc)
    Val_Loss.append(valid_loss)
    Val_Acc.append(valid_acc)
# Out:
# Epoch: 01 || EpochTime: 0m21s
# 	Train Loss: 1.841 || Train Acc: 31.62%
# 	 Val Loss: 1.349 ||  Val Acc: 48.52%
# Epoch: 02 || EpochTime: 0m21s
# 	Train Loss: 1.373 || Train Acc: 50.36%
# 	 Val Loss: 1.012 ||  Val Acc: 64.04%
# Epoch: 03 || EpochTime: 0m21s
# 	Train Loss: 1.129 || Train Acc: 59.61%
# 	 Val Loss: 0.919 ||  Val Acc: 69.01%
# Epoch: 04 || EpochTime: 0m21s
# 	Train Loss: 0.974 || Train Acc: 65.89%
# 	 Val Loss: 0.863 ||  Val Acc: 70.63%
# Epoch: 05 || EpochTime: 0m21s
# 	Train Loss: 0.862 || Train Acc: 69.98%
# 	 Val Loss: 0.769 ||  Val Acc: 74.11%
# Epoch: 06 || EpochTime: 0m21s
# 	Train Loss: 0.794 || Train Acc: 72.30%
# 	 Val Loss: 0.672 ||  Val Acc: 77.79%
# Epoch: 07 || EpochTime: 0m21s
# 	Train Loss: 0.730 || Train Acc: 74.69%
# 	 Val Loss: 0.546 ||  Val Acc: 81.88%
# Epoch: 08 || EpochTime: 0m21s
# 	Train Loss: 0.690 || Train Acc: 75.89%
# 	 Val Loss: 0.525 ||  Val Acc: 82.44%
# Epoch: 09 || EpochTime: 0m21s
# 	Train Loss: 0.649 || Train Acc: 77.43%
# 	 Val Loss: 0.550 ||  Val Acc: 82.18%
# Epoch: 10 || EpochTime: 0m21s
# 	Train Loss: 0.611 || Train Acc: 78.77%
# 	 Val Loss: 0.521 ||  Val Acc: 81.94%
# Epoch: 11 || EpochTime: 0m21s
# 	Train Loss: 0.583 || Train Acc: 79.71%
# 	 Val Loss: 0.420 ||  Val Acc: 85.66%
# Epoch: 12 || EpochTime: 0m21s
# 	Train Loss: 0.552 || Train Acc: 80.77%
# 	 Val Loss: 0.402 ||  Val Acc: 86.93%
# Epoch: 13 || EpochTime: 0m21s
# 	Train Loss: 0.533 || Train Acc: 81.43%
# 	 Val Loss: 0.385 ||  Val Acc: 87.34%
# Epoch: 14 || EpochTime: 0m21s
# 	Train Loss: 0.509 || Train Acc: 82.33%
# 	 Val Loss: 0.423 ||  Val Acc: 85.94%
# Epoch: 15 || EpochTime: 0m21s
# 	Train Loss: 0.482 || Train Acc: 83.15%
# 	 Val Loss: 0.370 ||  Val Acc: 87.44%
# Epoch: 16 || EpochTime: 0m21s
# 	Train Loss: 0.462 || Train Acc: 84.17%
# 	 Val Loss: 0.334 ||  Val Acc: 88.92%
# Epoch: 17 || EpochTime: 0m21s
# 	Train Loss: 0.452 || Train Acc: 84.15%
# 	 Val Loss: 0.337 ||  Val Acc: 88.65%
# Epoch: 18 || EpochTime: 0m22s
# 	Train Loss: 0.440 || Train Acc: 84.68%
# 	 Val Loss: 0.377 ||  Val Acc: 87.36%
# Epoch: 19 || EpochTime: 0m21s
# 	Train Loss: 0.414 || Train Acc: 85.66%
# 	 Val Loss: 0.314 ||  Val Acc: 89.38%
# Epoch: 20 || EpochTime: 0m21s
# 	Train Loss: 0.401 || Train Acc: 86.02%
# 	 Val Loss: 0.347 ||  Val Acc: 88.23%
# Epoch: 21 || EpochTime: 0m21s
# 	Train Loss: 0.395 || Train Acc: 86.12%
# 	 Val Loss: 0.308 ||  Val Acc: 89.83%
# Epoch: 22 || EpochTime: 0m21s
# 	Train Loss: 0.385 || Train Acc: 86.54%
# 	 Val Loss: 0.301 ||  Val Acc: 89.52%
# Epoch: 23 || EpochTime: 0m21s
# 	Train Loss: 0.377 || Train Acc: 86.80%
# 	 Val Loss: 0.295 ||  Val Acc: 89.89%
# Epoch: 24 || EpochTime: 0m21s
# 	Train Loss: 0.359 || Train Acc: 87.45%
# 	 Val Loss: 0.294 ||  Val Acc: 89.79%
# Epoch: 25 || EpochTime: 0m21s
# 	Train Loss: 0.350 || Train Acc: 87.85%
# 	 Val Loss: 0.285 ||  Val Acc: 90.72%
# Epoch: 26 || EpochTime: 0m21s
# 	Train Loss: 0.342 || Train Acc: 88.20%
# 	 Val Loss: 0.286 ||  Val Acc: 90.09%
# Epoch: 27 || EpochTime: 0m22s
# 	Train Loss: 0.338 || Train Acc: 88.25%
# 	 Val Loss: 0.277 ||  Val Acc: 90.76%
# Epoch: 28 || EpochTime: 0m21s
# 	Train Loss: 0.325 || Train Acc: 88.55%
# 	 Val Loss: 0.285 ||  Val Acc: 90.72%
# Epoch: 29 || EpochTime: 0m21s
# 	Train Loss: 0.317 || Train Acc: 88.86%
# 	 Val Loss: 0.271 ||  Val Acc: 91.40%
# Epoch: 30 || EpochTime: 0m21s
# 	Train Loss: 0.309 || Train Acc: 89.13%
# 	 Val Loss: 0.276 ||  Val Acc: 90.74%
# Epoch: 31 || EpochTime: 0m21s
# 	Train Loss: 0.306 || Train Acc: 89.38%
# 	 Val Loss: 0.274 ||  Val Acc: 91.02%
# Epoch: 32 || EpochTime: 0m21s
# 	Train Loss: 0.294 || Train Acc: 89.72%
# 	 Val Loss: 0.283 ||  Val Acc: 90.66%
# Epoch: 33 || EpochTime: 0m21s
# 	Train Loss: 0.285 || Train Acc: 89.96%
# 	 Val Loss: 0.261 ||  Val Acc: 91.40%
# Epoch: 34 || EpochTime: 0m21s
# 	Train Loss: 0.285 || Train Acc: 89.96%
# 	 Val Loss: 0.266 ||  Val Acc: 91.20%
# Epoch: 35 || EpochTime: 0m21s
# 	Train Loss: 0.277 || Train Acc: 90.33%
# 	 Val Loss: 0.282 ||  Val Acc: 90.86%
# Epoch: 36 || EpochTime: 0m22s
# 	Train Loss: 0.270 || Train Acc: 90.58%
# 	 Val Loss: 0.250 ||  Val Acc: 91.83%
# Epoch: 37 || EpochTime: 0m21s
# 	Train Loss: 0.270 || Train Acc: 90.62%
# 	 Val Loss: 0.276 ||  Val Acc: 91.42%
# Epoch: 38 || EpochTime: 0m21s
# 	Train Loss: 0.262 || Train Acc: 90.82%
# 	 Val Loss: 0.253 ||  Val Acc: 91.95%
# Epoch: 39 || EpochTime: 0m21s
# 	Train Loss: 0.255 || Train Acc: 91.14%
# 	 Val Loss: 0.258 ||  Val Acc: 91.97%
# Epoch: 40 || EpochTime: 0m21s
# 	Train Loss: 0.249 || Train Acc: 91.05%
# 	 Val Loss: 0.259 ||  Val Acc: 91.89%
# Epoch: 41 || EpochTime: 0m21s
# 	Train Loss: 0.244 || Train Acc: 91.47%
# 	 Val Loss: 0.257 ||  Val Acc: 92.15%
# Epoch: 42 || EpochTime: 0m21s
# 	Train Loss: 0.247 || Train Acc: 91.55%
# 	 Val Loss: 0.275 ||  Val Acc: 91.36%
# Epoch: 43 || EpochTime: 0m21s
# 	Train Loss: 0.242 || Train Acc: 91.65%
# 	 Val Loss: 0.266 ||  Val Acc: 91.71%
# Epoch: 44 || EpochTime: 0m21s
# 	Train Loss: 0.241 || Train Acc: 91.53%
# 	 Val Loss: 0.256 ||  Val Acc: 92.42%
# Epoch: 45 || EpochTime: 0m20s
# 	Train Loss: 0.233 || Train Acc: 91.77%
# 	 Val Loss: 0.248 ||  Val Acc: 92.23%
# Epoch: 46 || EpochTime: 0m21s
# 	Train Loss: 0.230 || Train Acc: 91.90%
# 	 Val Loss: 0.284 ||  Val Acc: 91.46%
# Epoch: 47 || EpochTime: 0m21s
# 	Train Loss: 0.225 || Train Acc: 92.14%
# 	 Val Loss: 0.268 ||  Val Acc: 91.69%
# Epoch: 48 || EpochTime: 0m21s
# 	Train Loss: 0.218 || Train Acc: 92.37%
# 	 Val Loss: 0.246 ||  Val Acc: 92.60%
# Epoch: 49 || EpochTime: 0m21s
# 	Train Loss: 0.210 || Train Acc: 92.65%
# 	 Val Loss: 0.236 ||  Val Acc: 92.46%
# Epoch: 50 || EpochTime: 0m21s
# 	Train Loss: 0.215 || Train Acc: 92.47%
# 	 Val Loss: 0.257 ||  Val Acc: 92.17%
# Epoch: 51 || EpochTime: 0m21s
# 	Train Loss: 0.210 || Train Acc: 92.67%
# 	 Val Loss: 0.247 ||  Val Acc: 92.66%
# Epoch: 52 || EpochTime: 0m22s
# 	Train Loss: 0.213 || Train Acc: 92.61%
# 	 Val Loss: 0.270 ||  Val Acc: 92.03%
# Epoch: 53 || EpochTime: 0m21s
# 	Train Loss: 0.208 || Train Acc: 92.88%
# 	 Val Loss: 0.272 ||  Val Acc: 92.17%
# Epoch: 54 || EpochTime: 0m21s
# 	Train Loss: 0.206 || Train Acc: 92.80%
# 	 Val Loss: 0.240 ||  Val Acc: 92.80%
# Epoch: 55 || EpochTime: 0m21s
# 	Train Loss: 0.193 || Train Acc: 93.36%
# 	 Val Loss: 0.290 ||  Val Acc: 91.93%
# Epoch: 56 || EpochTime: 0m21s
# 	Train Loss: 0.200 || Train Acc: 93.07%
# 	 Val Loss: 0.253 ||  Val Acc: 92.44%
# Epoch: 57 || EpochTime: 0m21s
# 	Train Loss: 0.197 || Train Acc: 93.14%
# 	 Val Loss: 0.266 ||  Val Acc: 92.68%
# Epoch: 58 || EpochTime: 0m21s
# 	Train Loss: 0.190 || Train Acc: 93.31%
# 	 Val Loss: 0.252 ||  Val Acc: 92.64%
# Epoch: 59 || EpochTime: 0m21s
# 	Train Loss: 0.189 || Train Acc: 93.44%
# 	 Val Loss: 0.260 ||  Val Acc: 92.25%
# Epoch: 60 || EpochTime: 0m21s
# 	Train Loss: 0.186 || Train Acc: 93.46%
# 	 Val Loss: 0.262 ||  Val Acc: 92.29%
# Epoch: 61 || EpochTime: 0m21s
# 	Train Loss: 0.155 || Train Acc: 94.78%
# 	 Val Loss: 0.219 ||  Val Acc: 93.55%
# Epoch: 62 || EpochTime: 0m21s
# 	Train Loss: 0.140 || Train Acc: 95.22%
# 	 Val Loss: 0.216 ||  Val Acc: 93.83%
# Epoch: 63 || EpochTime: 0m21s
# 	Train Loss: 0.137 || Train Acc: 95.17%
# 	 Val Loss: 0.218 ||  Val Acc: 93.81%
# Epoch: 64 || EpochTime: 0m21s
# 	Train Loss: 0.130 || Train Acc: 95.57%
# 	 Val Loss: 0.220 ||  Val Acc: 93.71%
# Epoch: 65 || EpochTime: 0m21s
# 	Train Loss: 0.131 || Train Acc: 95.53%
# 	 Val Loss: 0.214 ||  Val Acc: 93.95%
# Epoch: 66 || EpochTime: 0m21s
# 	Train Loss: 0.128 || Train Acc: 95.57%
# 	 Val Loss: 0.216 ||  Val Acc: 94.19%
# Epoch: 67 || EpochTime: 0m21s
# 	Train Loss: 0.125 || Train Acc: 95.73%
# 	 Val Loss: 0.219 ||  Val Acc: 93.97%
# Epoch: 68 || EpochTime: 0m21s
# 	Train Loss: 0.121 || Train Acc: 95.81%
# 	 Val Loss: 0.217 ||  Val Acc: 93.85%
# Epoch: 69 || EpochTime: 0m21s
# 	Train Loss: 0.122 || Train Acc: 95.82%
# 	 Val Loss: 0.219 ||  Val Acc: 93.81%
# Epoch: 70 || EpochTime: 0m21s
# 	Train Loss: 0.119 || Train Acc: 95.98%
# 	 Val Loss: 0.214 ||  Val Acc: 93.85%
# Epoch: 71 || EpochTime: 0m21s
# 	Train Loss: 0.117 || Train Acc: 95.96%
# 	 Val Loss: 0.215 ||  Val Acc: 93.91%
# Epoch: 72 || EpochTime: 0m21s
# 	Train Loss: 0.121 || Train Acc: 95.90%
# 	 Val Loss: 0.218 ||  Val Acc: 94.01%
# Epoch: 73 || EpochTime: 0m21s
# 	Train Loss: 0.118 || Train Acc: 96.01%
# 	 Val Loss: 0.222 ||  Val Acc: 93.91%
# Epoch: 74 || EpochTime: 0m21s
# 	Train Loss: 0.121 || Train Acc: 95.89%
# 	 Val Loss: 0.219 ||  Val Acc: 93.97%
# Epoch: 75 || EpochTime: 0m21s
# 	Train Loss: 0.117 || Train Acc: 96.01%
# 	 Val Loss: 0.214 ||  Val Acc: 94.28%
# Epoch: 76 || EpochTime: 0m21s
# 	Train Loss: 0.117 || Train Acc: 95.98%
# 	 Val Loss: 0.209 ||  Val Acc: 94.11%
# Epoch: 77 || EpochTime: 0m21s
# 	Train Loss: 0.114 || Train Acc: 96.07%
# 	 Val Loss: 0.217 ||  Val Acc: 93.99%
# Epoch: 78 || EpochTime: 0m21s
# 	Train Loss: 0.114 || Train Acc: 96.08%
# 	 Val Loss: 0.210 ||  Val Acc: 94.36%
# Epoch: 79 || EpochTime: 0m21s
# 	Train Loss: 0.110 || Train Acc: 96.27%
# 	 Val Loss: 0.208 ||  Val Acc: 94.09%
# Epoch: 80 || EpochTime: 0m21s
# 	Train Loss: 0.112 || Train Acc: 96.16%
# 	 Val Loss: 0.214 ||  Val Acc: 94.30%
# Epoch: 81 || EpochTime: 0m21s
# 	Train Loss: 0.110 || Train Acc: 96.14%
# 	 Val Loss: 0.212 ||  Val Acc: 94.32%
# Epoch: 82 || EpochTime: 0m21s
# 	Train Loss: 0.112 || Train Acc: 96.16%
# 	 Val Loss: 0.214 ||  Val Acc: 94.34%
# Epoch: 83 || EpochTime: 0m21s
# 	Train Loss: 0.113 || Train Acc: 96.13%
# 	 Val Loss: 0.210 ||  Val Acc: 94.22%
# Epoch: 84 || EpochTime: 0m21s
# 	Train Loss: 0.108 || Train Acc: 96.31%
# 	 Val Loss: 0.212 ||  Val Acc: 94.50%
# Epoch: 85 || EpochTime: 0m21s
# 	Train Loss: 0.110 || Train Acc: 96.32%
# 	 Val Loss: 0.214 ||  Val Acc: 94.19%
# Epoch: 86 || EpochTime: 0m21s
# 	Train Loss: 0.110 || Train Acc: 96.27%
# 	 Val Loss: 0.216 ||  Val Acc: 94.22%
# Epoch: 87 || EpochTime: 0m21s
# 	Train Loss: 0.111 || Train Acc: 96.26%
# 	 Val Loss: 0.218 ||  Val Acc: 94.30%
# Epoch: 88 || EpochTime: 0m21s
# 	Train Loss: 0.108 || Train Acc: 96.28%
# 	 Val Loss: 0.221 ||  Val Acc: 94.13%
# Epoch: 89 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.47%
# 	 Val Loss: 0.224 ||  Val Acc: 94.24%
# Epoch: 90 || EpochTime: 0m21s
# 	Train Loss: 0.108 || Train Acc: 96.25%
# 	 Val Loss: 0.218 ||  Val Acc: 94.36%
# Epoch: 91 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.50%
# 	 Val Loss: 0.216 ||  Val Acc: 94.13%
# Epoch: 92 || EpochTime: 0m21s
# 	Train Loss: 0.106 || Train Acc: 96.34%
# 	 Val Loss: 0.214 ||  Val Acc: 94.22%
# Epoch: 93 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.43%
# 	 Val Loss: 0.214 ||  Val Acc: 94.28%
# Epoch: 94 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.45%
# 	 Val Loss: 0.212 ||  Val Acc: 94.38%
# Epoch: 95 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.52%
# 	 Val Loss: 0.212 ||  Val Acc: 94.32%
# Epoch: 96 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.45%
# 	 Val Loss: 0.209 ||  Val Acc: 94.40%
# Epoch: 97 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.50%
# 	 Val Loss: 0.213 ||  Val Acc: 94.30%
# Epoch: 98 || EpochTime: 0m22s
# 	Train Loss: 0.103 || Train Acc: 96.48%
# 	 Val Loss: 0.209 ||  Val Acc: 94.38%
# Epoch: 99 || EpochTime: 0m21s
# 	Train Loss: 0.105 || Train Acc: 96.36%
# 	 Val Loss: 0.211 ||  Val Acc: 94.62%
# Epoch: 100 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.53%
# 	 Val Loss: 0.211 ||  Val Acc: 94.44%
# Epoch: 101 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.60%
# 	 Val Loss: 0.212 ||  Val Acc: 94.40%
# Epoch: 102 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.49%
# 	 Val Loss: 0.212 ||  Val Acc: 94.48%
# Epoch: 103 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.43%
# 	 Val Loss: 0.214 ||  Val Acc: 94.52%
# Epoch: 104 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.43%
# 	 Val Loss: 0.211 ||  Val Acc: 94.46%
# Epoch: 105 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.55%
# 	 Val Loss: 0.215 ||  Val Acc: 94.42%
# Epoch: 106 || EpochTime: 0m21s
# 	Train Loss: 0.097 || Train Acc: 96.74%
# 	 Val Loss: 0.214 ||  Val Acc: 94.54%
# Epoch: 107 || EpochTime: 0m21s
# 	Train Loss: 0.104 || Train Acc: 96.44%
# 	 Val Loss: 0.208 ||  Val Acc: 94.44%
# Epoch: 108 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.58%
# 	 Val Loss: 0.215 ||  Val Acc: 94.32%
# Epoch: 109 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.54%
# 	 Val Loss: 0.209 ||  Val Acc: 94.40%
# Epoch: 110 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.55%
# 	 Val Loss: 0.215 ||  Val Acc: 94.32%
# Epoch: 111 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.55%
# 	 Val Loss: 0.211 ||  Val Acc: 94.54%
# Epoch: 112 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.56%
# 	 Val Loss: 0.214 ||  Val Acc: 94.42%
# Epoch: 113 || EpochTime: 0m21s
# 	Train Loss: 0.105 || Train Acc: 96.41%
# 	 Val Loss: 0.211 ||  Val Acc: 94.38%
# Epoch: 114 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.46%
# 	 Val Loss: 0.213 ||  Val Acc: 94.44%
# Epoch: 115 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.50%
# 	 Val Loss: 0.213 ||  Val Acc: 94.48%
# Epoch: 116 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.60%
# 	 Val Loss: 0.212 ||  Val Acc: 94.48%
# Epoch: 117 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.58%
# 	 Val Loss: 0.215 ||  Val Acc: 94.36%
# Epoch: 118 || EpochTime: 0m21s
# 	Train Loss: 0.097 || Train Acc: 96.65%
# 	 Val Loss: 0.213 ||  Val Acc: 94.42%
# Epoch: 119 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.59%
# 	 Val Loss: 0.212 ||  Val Acc: 94.48%
# Epoch: 120 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.62%
# 	 Val Loss: 0.213 ||  Val Acc: 94.30%
# Epoch: 121 || EpochTime: 0m21s
# 	Train Loss: 0.105 || Train Acc: 96.36%
# 	 Val Loss: 0.211 ||  Val Acc: 94.66%
# Epoch: 122 || EpochTime: 0m21s
# 	Train Loss: 0.098 || Train Acc: 96.60%
# 	 Val Loss: 0.210 ||  Val Acc: 94.52%
# Epoch: 123 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.49%
# 	 Val Loss: 0.214 ||  Val Acc: 94.34%
# Epoch: 124 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.45%
# 	 Val Loss: 0.215 ||  Val Acc: 94.24%
# Epoch: 125 || EpochTime: 0m21s
# 	Train Loss: 0.098 || Train Acc: 96.68%
# 	 Val Loss: 0.211 ||  Val Acc: 94.44%
# Epoch: 126 || EpochTime: 0m21s
# 	Train Loss: 0.096 || Train Acc: 96.72%
# 	 Val Loss: 0.214 ||  Val Acc: 94.38%
# Epoch: 127 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.58%
# 	 Val Loss: 0.217 ||  Val Acc: 94.32%
# Epoch: 128 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.48%
# 	 Val Loss: 0.213 ||  Val Acc: 94.30%
# Epoch: 129 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.41%
# 	 Val Loss: 0.214 ||  Val Acc: 94.54%
# Epoch: 130 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.48%
# 	 Val Loss: 0.212 ||  Val Acc: 94.42%
# Epoch: 131 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.52%
# 	 Val Loss: 0.215 ||  Val Acc: 94.48%
# Epoch: 132 || EpochTime: 0m21s
# 	Train Loss: 0.099 || Train Acc: 96.65%
# 	 Val Loss: 0.214 ||  Val Acc: 94.30%
# Epoch: 133 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.61%
# 	 Val Loss: 0.210 ||  Val Acc: 94.72%
# Epoch: 134 || EpochTime: 0m21s
# 	Train Loss: 0.096 || Train Acc: 96.67%
# 	 Val Loss: 0.211 ||  Val Acc: 94.44%
# Epoch: 135 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.49%
# 	 Val Loss: 0.215 ||  Val Acc: 94.56%
# Epoch: 136 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.52%
# 	 Val Loss: 0.212 ||  Val Acc: 94.60%
# Epoch: 137 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.62%
# 	 Val Loss: 0.214 ||  Val Acc: 94.40%
# Epoch: 138 || EpochTime: 0m21s
# 	Train Loss: 0.099 || Train Acc: 96.68%
# 	 Val Loss: 0.216 ||  Val Acc: 94.26%
# Epoch: 139 || EpochTime: 0m21s
# 	Train Loss: 0.098 || Train Acc: 96.65%
# 	 Val Loss: 0.217 ||  Val Acc: 94.19%
# Epoch: 140 || EpochTime: 0m21s
# 	Train Loss: 0.105 || Train Acc: 96.36%
# 	 Val Loss: 0.212 ||  Val Acc: 94.50%
# Epoch: 141 || EpochTime: 0m21s
# 	Train Loss: 0.104 || Train Acc: 96.38%
# 	 Val Loss: 0.213 ||  Val Acc: 94.60%
# Epoch: 142 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.55%
# 	 Val Loss: 0.216 ||  Val Acc: 94.42%
# Epoch: 143 || EpochTime: 0m21s
# 	Train Loss: 0.104 || Train Acc: 96.31%
# 	 Val Loss: 0.214 ||  Val Acc: 94.58%
# Epoch: 144 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.54%
# 	 Val Loss: 0.214 ||  Val Acc: 94.28%
# Epoch: 145 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.54%
# 	 Val Loss: 0.215 ||  Val Acc: 94.48%
# Epoch: 146 || EpochTime: 0m21s
# 	Train Loss: 0.097 || Train Acc: 96.69%
# 	 Val Loss: 0.216 ||  Val Acc: 94.36%
# Epoch: 147 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.53%
# 	 Val Loss: 0.212 ||  Val Acc: 94.34%
# Epoch: 148 || EpochTime: 0m21s
# 	Train Loss: 0.096 || Train Acc: 96.72%
# 	 Val Loss: 0.214 ||  Val Acc: 94.48%
# Epoch: 149 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.44%
# 	 Val Loss: 0.213 ||  Val Acc: 94.40%
# Epoch: 150 || EpochTime: 0m21s
# 	Train Loss: 0.098 || Train Acc: 96.68%
# 	 Val Loss: 0.214 ||  Val Acc: 94.40%

# %%
# visualize the loss as the network trained
def get_loss_plot(train_loss, val_loss):
    plt.plot(range(len(train_loss)),train_loss)
    plt.plot(range(len(train_loss)),val_loss)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.title('Loss')
    plt.legend(['Training Loss', 'Validation Loss'])
    plt.savefig('Model_2.png')
    plt.show()
    
    
# Prints training loss and validation loss 
get_loss_plot(Train_Loss, Val_Loss)

# %% [markdown]
# #5.  Evaluate Best Saved Model on Test Dataset

# %%
# Load saved model's parameters
model.load_state_dict(torch.load('Model_2.pt'))

# Calculate test loss and accuracy
test_loss, test_acc = evaluate(model, test_dataloader, criterion, device)


print(f'Test Loss: {test_loss:.3f} || Test Acc: {test_acc*100:.2f}%')
# Out:
# Test Loss: 0.211 || Test Acc: 94.39%
