# %%
import torch, torchvision
import torchvision.transforms as transforms
import torch.nn as nn, torch.nn.functional as F
import torch.optim as optim, torch.utils.data as data
import torchvision.datasets as datasets
import time, copy, random, os, numpy as np
import matplotlib.pyplot as plt
from torchvision.transforms.autoaugment import AutoAugmentPolicy
from torch.optim.lr_scheduler import ReduceLROnPlateau, OneCycleLR
from torch.utils.data import random_split
from torchsummary import summary

# %%
BATCH_SIZE = 64
INPUT_SIZE = (3, 32, 32)
EPOCHS = 150
LEARNING_RATE = 1e-3

# %%
#Verify GPU
# !nvidia-smi
# Out:
# Tue Apr 11 18:02:05 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    44W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Specify device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Sets the seed for numpy and torch to make sure functions with a random component behave deterministically
# torch.backends.cudnn.deterministic = true sets the CuDNN to deterministic mode.
# This function allows us to run experiments 100% deterministically.
# https://gist.github.com/ihoromi4/b681a9088f348942b01711f251e5f964

def seed_everything(seed=1234):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything()

# %% [markdown]
# # 1.  Load and Batch the Data

# %%
def get_data_loaders(batch_size, root = '.data', valid_ratio = 0.1):
  
    #means and stds for the 3 channels of the dataset
    means = (0.4914, 0.4822, 0.4465)
    stds = (0.2023, 0.1994, 0.2010)

    #   Performs the following data augmentations on the training set:
    #       1.  Random Rotation:  
    #       2.  RandomHorizontalFlip
    #       3.  Random Crop
    #       4.  AutoAugment: AutoAugmention policies learned from the CIFAR10 dataset
    #           AutoAugment: Learning Augmentation Strategies from Data" <https://arxiv.org/pdf/1805.09501.pdf>`
    train_transforms = transforms.Compose([
                           transforms.RandomRotation(5),
                           transforms.RandomHorizontalFlip(0.5),
                           transforms.RandomCrop(32, padding = 2),
                           transforms.AutoAugment(AutoAugmentPolicy.CIFAR10),
                           transforms.ToTensor(),  # convert data to torch.FloatTensor: CxHxW
                           transforms.Normalize(mean = means, std = stds, inplace=True), #Range is in [-1,1], data = (data - mean)/std
                       ])

    test_transforms = transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize(mean = means, std = stds, inplace=True),
                       ])

    # choose the training and test datasets
    train_data = datasets.CIFAR10(root, 
                              train = True, 
                              download = True, 
                              transform = train_transforms)
    
    test_data = datasets.CIFAR10(root, 
                             train = False, 
                             download = True, 
                             transform = test_transforms)
    
    # obtain number of training/validation examples that will be used to create the respective datasets 
    n_train_examples = int((1 - valid_ratio) * len(train_data))
    n_valid_examples = int(valid_ratio* len(train_data))

    train_data, valid_data = random_split(train_data, [n_train_examples, n_valid_examples])
    
    #Creates a deep copy
    valid_data = copy.deepcopy(valid_data)  
    valid_data.dataset.transform = test_transforms

    # load training data in batches
    train_dataloader = data.DataLoader(train_data,
                                 shuffle = True,
                                 batch_size = batch_size,
                                 num_workers=2, 
                                 pin_memory=True)   #pin_memory speeds transfer of data from CPU to GPU

    # load validation data in batches
    valid_dataloader = data.DataLoader(valid_data,
                                 batch_size = batch_size,
                                 num_workers=2, 
                                 pin_memory=True)

    # load test data in batches
    test_dataloader = data.DataLoader(test_data,
                                batch_size = batch_size,
                                num_workers=2, 
                                pin_memory=True)
  
    return train_dataloader, valid_dataloader, test_dataloader

# %%
# Load and batch the data
train_dataloader, valid_dataloader, test_dataloader = get_data_loaders(BATCH_SIZE)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to .data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:13<00:00, 13102125.68it/s]
# Extracting .data/cifar-10-python.tar.gz to .data
# Files already downloaded and verified

# %% [markdown]
# # 2.  Define the Network

# %%
'''ResNet in PyTorch.
For Pre-activation ResNet, see 'preact_resnet.py'.
Reference:
[1] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun
    Deep Residual Learning for Image Recognition. arXiv:1512.03385
'''

#Residual Block
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=3,padding=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

#1. Convolutional Layer: conv1
#2. Residual Layers: layer1, layer2, layer3, layer4
#3. Fully Connected Layer: linear
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 32

        self.conv1 = nn.Conv2d(3, 32, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 128, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 256, num_blocks[3], stride=2)
        self.linear = nn.Linear(256*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

#ResNet18 has 4 residual layers, each composed of a specifed number of residual blocks
def ResNet18():
    return ResNet(BasicBlock, [2,2,2,2])

# %% [markdown]
# # 3.  Specify Model, Loss Function, Optimizer, and Scheduler

# %%
# Specify the model, loss function, and optimizer; move model to device
model = ResNet18().to(device)
criterion = nn.CrossEntropyLoss()
#optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
optimizer = torch.optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=0.9)

# Specify scheduler
#scheduler = ReduceLROnPlateau(optimizer, 'min')

# %%
# Check total number of parameters
summary(model, input_size=INPUT_SIZE)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#             Conv2d-3           [-1, 64, 32, 32]          18,432
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#             Conv2d-7           [-1, 64, 32, 32]          18,432
#        BatchNorm2d-8           [-1, 64, 32, 32]             128
#         BasicBlock-9           [-1, 64, 32, 32]               0
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#            Conv2d-12           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-13           [-1, 64, 32, 32]             128
#        BasicBlock-14           [-1, 64, 32, 32]               0
#            Conv2d-15          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#            Conv2d-19          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-20          [-1, 128, 16, 16]             256
#        BasicBlock-21          [-1, 128, 16, 16]               0
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#            Conv2d-24          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-25          [-1, 128, 16, 16]             256
#        BasicBlock-26          [-1, 128, 16, 16]               0
#            Conv2d-27            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-28            [-1, 128, 8, 8]             256
#            Conv2d-29            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-30            [-1, 128, 8, 8]             256
#            Conv2d-31            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-32            [-1, 128, 8, 8]             256
#        BasicBlock-33            [-1, 128, 8, 8]               0
#            Conv2d-34            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-35            [-1, 128, 8, 8]             256
#            Conv2d-36            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-37            [-1, 128, 8, 8]             256
#        BasicBlock-38            [-1, 128, 8, 8]               0
#            Conv2d-39            [-1, 256, 4, 4]         294,912
#       BatchNorm2d-40            [-1, 256, 4, 4]             512
#            Conv2d-41            [-1, 256, 4, 4]         589,824
#       BatchNorm2d-42            [-1, 256, 4, 4]             512
#            Conv2d-43            [-1, 256, 4, 4]         294,912
#       BatchNorm2d-44            [-1, 256, 4, 4]             512
#        BasicBlock-45            [-1, 256, 4, 4]               0
#            Conv2d-46            [-1, 256, 4, 4]         589,824
#       BatchNorm2d-47            [-1, 256, 4, 4]             512
#            Conv2d-48            [-1, 256, 4, 4]         589,824
#       BatchNorm2d-49            [-1, 256, 4, 4]             512
#        BasicBlock-50            [-1, 256, 4, 4]               0
#            Linear-51                   [-1, 10]           2,570
# ================================================================
# Total params: 3,843,114
# Trainable params: 3,843,114
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 10.63
# Params size (MB): 14.66
# Estimated Total Size (MB): 25.30
# ----------------------------------------------------------------

# %% [markdown]
# #4. Training and Validation

# %%
# accuracy is the fraction of predictions the model got correct
def calculate_accuracy(y_pred, y):
    top_pred = y_pred.argmax(1, keepdim = True)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    acc = correct.float() / y.shape[0]
    return acc

# time interval for each epoch
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
def train(model, iterator, optimizer, criterion, device):
    
    # Tracks training loss and accuracy as model trains
    epoch_loss = 0
    epoch_acc = 0
    #lrs = []

    # Prep model for training
    model.train()

    for (x, y) in iterator:
        # Move inputs and labels to device
        x = x.to(device)
        y = y.to(device)
        
        # Clear the gradients of all optimized variables
        optimizer.zero_grad()

        # Forward pass: compute predicted outputs by passing inputs to the model        
        y_pred = model(x)
        
        # Calculate the loss
        loss = criterion(y_pred, y)
        
        # Calculate the accuracy
        acc = calculate_accuracy(y_pred, y)
        
        # Backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()

        #OneCycleLr Scheduler
        #scheduler.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def evaluate(model, iterator, criterion, device):
    # Keeps track of validation loss and  accuracy
    epoch_loss = 0
    epoch_acc = 0
    
    # Prep model for evaluation
    model.eval()
    
    with torch.no_grad():
        
        for (x, y) in iterator:

            x = x.to(device)
            y = y.to(device)

            # Forward Pass
            y_pred = model(x)
            # Calculate the validation loss
            loss = criterion(y_pred, y)
            #Calculate the validation accuracy
            acc = calculate_accuracy(y_pred, y)

            #Record validation loss
            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
# Train and Validate the model:

# Tracks average training loss and accuracy per epoch
#  and tracks average validation loss and accuracy per epoch
Train_Loss = []
Train_Acc = []
Val_Loss = []
Val_Acc = []


# Tracks best validation loss
best_valid_loss = float('inf')
for epoch in range(EPOCHS):
    # Epoch start time
    start_time = time.monotonic()


    train_loss, train_acc = train(model, train_dataloader, optimizer, criterion, device)
    valid_loss, valid_acc = evaluate(model, valid_dataloader, criterion, device)
  

    # OnReducePlateau is a scheduler monitoring validation loss
    #scheduler.step(valid_loss)

    # Saves model with best validation loss in a state dictionary
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(),'Model.pt')
    # Epoch end time
    end_time = time.monotonic()

    # Prints training/validation statistics as well as epoch time
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    print(f'Epoch: {epoch+1:02} || EpochTime: {epoch_mins}m{epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} || Train Acc: {train_acc*100:.2f}%')
    print(f'\t Val Loss: {valid_loss:.3f} ||  Val Acc: {valid_acc*100:.2f}%')

    Train_Loss.append(train_loss)
    Train_Acc.append(train_acc)
    Val_Loss.append(valid_loss)
    Val_Acc.append(valid_acc)
# Out:
# Epoch: 01 || EpochTime: 0m22s
# 	Train Loss: 1.823 || Train Acc: 33.03%
# 	 Val Loss: 1.396 ||  Val Acc: 49.29%
# Epoch: 02 || EpochTime: 0m21s
# 	Train Loss: 1.428 || Train Acc: 48.76%
# 	 Val Loss: 1.042 ||  Val Acc: 63.37%
# Epoch: 03 || EpochTime: 0m21s
# 	Train Loss: 1.206 || Train Acc: 57.10%
# 	 Val Loss: 0.903 ||  Val Acc: 68.08%
# Epoch: 04 || EpochTime: 0m21s
# 	Train Loss: 1.056 || Train Acc: 62.63%
# 	 Val Loss: 0.817 ||  Val Acc: 71.18%
# Epoch: 05 || EpochTime: 0m21s
# 	Train Loss: 0.955 || Train Acc: 66.17%
# 	 Val Loss: 0.704 ||  Val Acc: 74.78%
# Epoch: 06 || EpochTime: 0m21s
# 	Train Loss: 0.885 || Train Acc: 68.90%
# 	 Val Loss: 0.703 ||  Val Acc: 75.73%
# Epoch: 07 || EpochTime: 0m21s
# 	Train Loss: 0.823 || Train Acc: 71.18%
# 	 Val Loss: 0.609 ||  Val Acc: 78.50%
# Epoch: 08 || EpochTime: 0m21s
# 	Train Loss: 0.779 || Train Acc: 72.86%
# 	 Val Loss: 0.652 ||  Val Acc: 77.47%
# Epoch: 09 || EpochTime: 0m21s
# 	Train Loss: 0.744 || Train Acc: 74.08%
# 	 Val Loss: 0.568 ||  Val Acc: 80.38%
# Epoch: 10 || EpochTime: 0m21s
# 	Train Loss: 0.707 || Train Acc: 75.48%
# 	 Val Loss: 0.600 ||  Val Acc: 79.61%
# Epoch: 11 || EpochTime: 0m21s
# 	Train Loss: 0.674 || Train Acc: 76.58%
# 	 Val Loss: 0.491 ||  Val Acc: 83.43%
# Epoch: 12 || EpochTime: 0m22s
# 	Train Loss: 0.643 || Train Acc: 77.63%
# 	 Val Loss: 0.480 ||  Val Acc: 83.11%
# Epoch: 13 || EpochTime: 0m21s
# 	Train Loss: 0.629 || Train Acc: 78.20%
# 	 Val Loss: 0.497 ||  Val Acc: 83.07%
# Epoch: 14 || EpochTime: 0m21s
# 	Train Loss: 0.600 || Train Acc: 79.09%
# 	 Val Loss: 0.462 ||  Val Acc: 84.18%
# Epoch: 15 || EpochTime: 0m21s
# 	Train Loss: 0.583 || Train Acc: 79.81%
# 	 Val Loss: 0.472 ||  Val Acc: 84.10%
# Epoch: 16 || EpochTime: 0m21s
# 	Train Loss: 0.569 || Train Acc: 80.24%
# 	 Val Loss: 0.411 ||  Val Acc: 86.08%
# Epoch: 17 || EpochTime: 0m21s
# 	Train Loss: 0.552 || Train Acc: 80.72%
# 	 Val Loss: 0.429 ||  Val Acc: 85.48%
# Epoch: 18 || EpochTime: 0m21s
# 	Train Loss: 0.534 || Train Acc: 81.44%
# 	 Val Loss: 0.399 ||  Val Acc: 86.53%
# Epoch: 19 || EpochTime: 0m21s
# 	Train Loss: 0.517 || Train Acc: 82.02%
# 	 Val Loss: 0.384 ||  Val Acc: 86.37%
# Epoch: 20 || EpochTime: 0m21s
# 	Train Loss: 0.500 || Train Acc: 82.54%
# 	 Val Loss: 0.372 ||  Val Acc: 87.06%
# Epoch: 21 || EpochTime: 0m22s
# 	Train Loss: 0.497 || Train Acc: 82.64%
# 	 Val Loss: 0.415 ||  Val Acc: 86.04%
# Epoch: 22 || EpochTime: 0m21s
# 	Train Loss: 0.484 || Train Acc: 83.03%
# 	 Val Loss: 0.368 ||  Val Acc: 87.70%
# Epoch: 23 || EpochTime: 0m21s
# 	Train Loss: 0.474 || Train Acc: 83.52%
# 	 Val Loss: 0.399 ||  Val Acc: 86.25%
# Epoch: 24 || EpochTime: 0m21s
# 	Train Loss: 0.461 || Train Acc: 83.90%
# 	 Val Loss: 0.393 ||  Val Acc: 85.90%
# Epoch: 25 || EpochTime: 0m21s
# 	Train Loss: 0.453 || Train Acc: 84.18%
# 	 Val Loss: 0.359 ||  Val Acc: 87.78%
# Epoch: 26 || EpochTime: 0m21s
# 	Train Loss: 0.447 || Train Acc: 84.43%
# 	 Val Loss: 0.376 ||  Val Acc: 87.58%
# Epoch: 27 || EpochTime: 0m21s
# 	Train Loss: 0.425 || Train Acc: 85.08%
# 	 Val Loss: 0.353 ||  Val Acc: 88.09%
# Epoch: 28 || EpochTime: 0m21s
# 	Train Loss: 0.424 || Train Acc: 85.21%
# 	 Val Loss: 0.407 ||  Val Acc: 86.77%
# Epoch: 29 || EpochTime: 0m21s
# 	Train Loss: 0.414 || Train Acc: 85.39%
# 	 Val Loss: 0.377 ||  Val Acc: 86.91%
# Epoch: 30 || EpochTime: 0m21s
# 	Train Loss: 0.407 || Train Acc: 86.00%
# 	 Val Loss: 0.356 ||  Val Acc: 87.52%
# Epoch: 31 || EpochTime: 0m21s
# 	Train Loss: 0.397 || Train Acc: 86.08%
# 	 Val Loss: 0.339 ||  Val Acc: 88.71%
# Epoch: 32 || EpochTime: 0m21s
# 	Train Loss: 0.398 || Train Acc: 85.99%
# 	 Val Loss: 0.385 ||  Val Acc: 87.32%
# Epoch: 33 || EpochTime: 0m21s
# 	Train Loss: 0.390 || Train Acc: 86.47%
# 	 Val Loss: 0.332 ||  Val Acc: 88.55%
# Epoch: 34 || EpochTime: 0m21s
# 	Train Loss: 0.381 || Train Acc: 86.80%
# 	 Val Loss: 0.335 ||  Val Acc: 88.47%
# Epoch: 35 || EpochTime: 0m21s
# 	Train Loss: 0.381 || Train Acc: 86.78%
# 	 Val Loss: 0.330 ||  Val Acc: 88.75%
# Epoch: 36 || EpochTime: 0m21s
# 	Train Loss: 0.373 || Train Acc: 87.06%
# 	 Val Loss: 0.333 ||  Val Acc: 88.92%
# Epoch: 37 || EpochTime: 0m21s
# 	Train Loss: 0.366 || Train Acc: 87.23%
# 	 Val Loss: 0.325 ||  Val Acc: 88.79%
# Epoch: 38 || EpochTime: 0m22s
# 	Train Loss: 0.352 || Train Acc: 87.63%
# 	 Val Loss: 0.307 ||  Val Acc: 89.34%
# Epoch: 39 || EpochTime: 0m21s
# 	Train Loss: 0.351 || Train Acc: 87.70%
# 	 Val Loss: 0.353 ||  Val Acc: 87.97%
# Epoch: 40 || EpochTime: 0m21s
# 	Train Loss: 0.350 || Train Acc: 87.73%
# 	 Val Loss: 0.307 ||  Val Acc: 90.21%
# Epoch: 41 || EpochTime: 0m21s
# 	Train Loss: 0.340 || Train Acc: 88.09%
# 	 Val Loss: 0.338 ||  Val Acc: 88.71%
# Epoch: 42 || EpochTime: 0m21s
# 	Train Loss: 0.337 || Train Acc: 88.27%
# 	 Val Loss: 0.312 ||  Val Acc: 89.44%
# Epoch: 43 || EpochTime: 0m21s
# 	Train Loss: 0.326 || Train Acc: 88.55%
# 	 Val Loss: 0.315 ||  Val Acc: 90.01%
# Epoch: 44 || EpochTime: 0m21s
# 	Train Loss: 0.326 || Train Acc: 88.71%
# 	 Val Loss: 0.302 ||  Val Acc: 90.05%
# Epoch: 45 || EpochTime: 0m21s
# 	Train Loss: 0.317 || Train Acc: 89.00%
# 	 Val Loss: 0.302 ||  Val Acc: 89.97%
# Epoch: 46 || EpochTime: 0m21s
# 	Train Loss: 0.319 || Train Acc: 88.89%
# 	 Val Loss: 0.360 ||  Val Acc: 89.02%
# Epoch: 47 || EpochTime: 0m21s
# 	Train Loss: 0.314 || Train Acc: 88.90%
# 	 Val Loss: 0.296 ||  Val Acc: 89.99%
# Epoch: 48 || EpochTime: 0m22s
# 	Train Loss: 0.310 || Train Acc: 89.08%
# 	 Val Loss: 0.315 ||  Val Acc: 89.91%
# Epoch: 49 || EpochTime: 0m21s
# 	Train Loss: 0.304 || Train Acc: 89.34%
# 	 Val Loss: 0.299 ||  Val Acc: 90.21%
# Epoch: 50 || EpochTime: 0m21s
# 	Train Loss: 0.302 || Train Acc: 89.45%
# 	 Val Loss: 0.316 ||  Val Acc: 89.93%
# Epoch: 51 || EpochTime: 0m21s
# 	Train Loss: 0.299 || Train Acc: 89.65%
# 	 Val Loss: 0.296 ||  Val Acc: 90.68%
# Epoch: 52 || EpochTime: 0m21s
# 	Train Loss: 0.292 || Train Acc: 89.87%
# 	 Val Loss: 0.296 ||  Val Acc: 90.25%
# Epoch: 53 || EpochTime: 0m21s
# 	Train Loss: 0.295 || Train Acc: 89.67%
# 	 Val Loss: 0.287 ||  Val Acc: 90.59%
# Epoch: 54 || EpochTime: 0m21s
# 	Train Loss: 0.286 || Train Acc: 90.05%
# 	 Val Loss: 0.294 ||  Val Acc: 90.49%
# Epoch: 55 || EpochTime: 0m21s
# 	Train Loss: 0.282 || Train Acc: 90.25%
# 	 Val Loss: 0.292 ||  Val Acc: 90.90%
# Epoch: 56 || EpochTime: 0m21s
# 	Train Loss: 0.279 || Train Acc: 90.22%
# 	 Val Loss: 0.319 ||  Val Acc: 89.95%
# Epoch: 57 || EpochTime: 0m21s
# 	Train Loss: 0.274 || Train Acc: 90.50%
# 	 Val Loss: 0.305 ||  Val Acc: 90.82%
# Epoch: 58 || EpochTime: 0m21s
# 	Train Loss: 0.274 || Train Acc: 90.46%
# 	 Val Loss: 0.288 ||  Val Acc: 91.00%
# Epoch: 59 || EpochTime: 0m21s
# 	Train Loss: 0.266 || Train Acc: 90.62%
# 	 Val Loss: 0.295 ||  Val Acc: 90.57%
# Epoch: 60 || EpochTime: 0m21s
# 	Train Loss: 0.264 || Train Acc: 90.67%
# 	 Val Loss: 0.303 ||  Val Acc: 90.51%
# Epoch: 61 || EpochTime: 0m21s
# 	Train Loss: 0.259 || Train Acc: 90.95%
# 	 Val Loss: 0.295 ||  Val Acc: 90.82%
# Epoch: 62 || EpochTime: 0m21s
# 	Train Loss: 0.266 || Train Acc: 90.95%
# 	 Val Loss: 0.284 ||  Val Acc: 90.98%
# Epoch: 63 || EpochTime: 0m21s
# 	Train Loss: 0.262 || Train Acc: 90.81%
# 	 Val Loss: 0.308 ||  Val Acc: 91.00%
# Epoch: 64 || EpochTime: 0m22s
# 	Train Loss: 0.255 || Train Acc: 91.07%
# 	 Val Loss: 0.293 ||  Val Acc: 90.76%
# Epoch: 65 || EpochTime: 0m21s
# 	Train Loss: 0.259 || Train Acc: 90.99%
# 	 Val Loss: 0.277 ||  Val Acc: 91.63%
# Epoch: 66 || EpochTime: 0m21s
# 	Train Loss: 0.249 || Train Acc: 91.48%
# 	 Val Loss: 0.296 ||  Val Acc: 90.51%
# Epoch: 67 || EpochTime: 0m22s
# 	Train Loss: 0.244 || Train Acc: 91.49%
# 	 Val Loss: 0.285 ||  Val Acc: 91.02%
# Epoch: 68 || EpochTime: 0m21s
# 	Train Loss: 0.251 || Train Acc: 91.28%
# 	 Val Loss: 0.319 ||  Val Acc: 89.95%
# Epoch: 69 || EpochTime: 0m21s
# 	Train Loss: 0.246 || Train Acc: 91.41%
# 	 Val Loss: 0.297 ||  Val Acc: 91.55%
# Epoch: 70 || EpochTime: 0m21s
# 	Train Loss: 0.243 || Train Acc: 91.48%
# 	 Val Loss: 0.289 ||  Val Acc: 91.20%
# Epoch: 71 || EpochTime: 0m21s
# 	Train Loss: 0.243 || Train Acc: 91.48%
# 	 Val Loss: 0.295 ||  Val Acc: 90.98%
# Epoch: 72 || EpochTime: 0m21s
# 	Train Loss: 0.240 || Train Acc: 91.72%
# 	 Val Loss: 0.291 ||  Val Acc: 91.32%
# Epoch: 73 || EpochTime: 0m22s
# 	Train Loss: 0.237 || Train Acc: 91.69%
# 	 Val Loss: 0.268 ||  Val Acc: 91.20%
# Epoch: 74 || EpochTime: 0m21s
# 	Train Loss: 0.236 || Train Acc: 91.67%
# 	 Val Loss: 0.311 ||  Val Acc: 90.96%
# Epoch: 75 || EpochTime: 0m21s
# 	Train Loss: 0.228 || Train Acc: 92.13%
# 	 Val Loss: 0.323 ||  Val Acc: 90.01%
# Epoch: 76 || EpochTime: 0m21s
# 	Train Loss: 0.231 || Train Acc: 92.01%
# 	 Val Loss: 0.286 ||  Val Acc: 90.90%
# Epoch: 77 || EpochTime: 0m22s
# 	Train Loss: 0.231 || Train Acc: 92.05%
# 	 Val Loss: 0.279 ||  Val Acc: 91.36%
# Epoch: 78 || EpochTime: 0m22s
# 	Train Loss: 0.224 || Train Acc: 92.17%
# 	 Val Loss: 0.279 ||  Val Acc: 91.52%
# Epoch: 79 || EpochTime: 0m21s
# 	Train Loss: 0.223 || Train Acc: 92.14%
# 	 Val Loss: 0.278 ||  Val Acc: 91.75%
# Epoch: 80 || EpochTime: 0m21s
# 	Train Loss: 0.217 || Train Acc: 92.44%
# 	 Val Loss: 0.276 ||  Val Acc: 91.61%
# Epoch: 81 || EpochTime: 0m21s
# 	Train Loss: 0.218 || Train Acc: 92.52%
# 	 Val Loss: 0.285 ||  Val Acc: 91.52%
# Epoch: 82 || EpochTime: 0m21s
# 	Train Loss: 0.218 || Train Acc: 92.33%
# 	 Val Loss: 0.297 ||  Val Acc: 91.18%
# Epoch: 83 || EpochTime: 0m21s
# 	Train Loss: 0.215 || Train Acc: 92.56%
# 	 Val Loss: 0.285 ||  Val Acc: 91.32%
# Epoch: 84 || EpochTime: 0m21s
# 	Train Loss: 0.216 || Train Acc: 92.39%
# 	 Val Loss: 0.292 ||  Val Acc: 91.42%
# Epoch: 85 || EpochTime: 0m22s
# 	Train Loss: 0.212 || Train Acc: 92.56%
# 	 Val Loss: 0.285 ||  Val Acc: 91.73%
# Epoch: 86 || EpochTime: 0m21s
# 	Train Loss: 0.215 || Train Acc: 92.58%
# 	 Val Loss: 0.296 ||  Val Acc: 91.24%
# Epoch: 87 || EpochTime: 0m21s
# 	Train Loss: 0.209 || Train Acc: 92.73%
# 	 Val Loss: 0.308 ||  Val Acc: 91.00%
# Epoch: 88 || EpochTime: 0m21s
# 	Train Loss: 0.207 || Train Acc: 92.80%
# 	 Val Loss: 0.286 ||  Val Acc: 91.59%
# Epoch: 89 || EpochTime: 0m21s
# 	Train Loss: 0.208 || Train Acc: 92.66%
# 	 Val Loss: 0.278 ||  Val Acc: 91.36%
# Epoch: 90 || EpochTime: 0m21s
# 	Train Loss: 0.203 || Train Acc: 92.83%
# 	 Val Loss: 0.260 ||  Val Acc: 91.87%
# Epoch: 91 || EpochTime: 0m21s
# 	Train Loss: 0.204 || Train Acc: 92.85%
# 	 Val Loss: 0.275 ||  Val Acc: 91.69%
# Epoch: 92 || EpochTime: 0m21s
# 	Train Loss: 0.201 || Train Acc: 93.11%
# 	 Val Loss: 0.296 ||  Val Acc: 91.61%
# Epoch: 93 || EpochTime: 0m21s
# 	Train Loss: 0.202 || Train Acc: 93.00%
# 	 Val Loss: 0.288 ||  Val Acc: 91.87%
# Epoch: 94 || EpochTime: 0m21s
# 	Train Loss: 0.197 || Train Acc: 93.17%
# 	 Val Loss: 0.274 ||  Val Acc: 92.03%
# Epoch: 95 || EpochTime: 0m21s
# 	Train Loss: 0.198 || Train Acc: 93.13%
# 	 Val Loss: 0.279 ||  Val Acc: 91.55%
# Epoch: 96 || EpochTime: 0m22s
# 	Train Loss: 0.201 || Train Acc: 93.10%
# 	 Val Loss: 0.272 ||  Val Acc: 91.99%
# Epoch: 97 || EpochTime: 0m21s
# 	Train Loss: 0.195 || Train Acc: 93.15%
# 	 Val Loss: 0.244 ||  Val Acc: 92.27%
# Epoch: 98 || EpochTime: 0m22s
# 	Train Loss: 0.192 || Train Acc: 93.30%
# 	 Val Loss: 0.287 ||  Val Acc: 91.52%
# Epoch: 99 || EpochTime: 0m21s
# 	Train Loss: 0.191 || Train Acc: 93.53%
# 	 Val Loss: 0.275 ||  Val Acc: 91.79%
# Epoch: 100 || EpochTime: 0m21s
# 	Train Loss: 0.188 || Train Acc: 93.37%
# 	 Val Loss: 0.262 ||  Val Acc: 92.41%
# Epoch: 101 || EpochTime: 0m21s
# 	Train Loss: 0.187 || Train Acc: 93.38%
# 	 Val Loss: 0.308 ||  Val Acc: 91.20%
# Epoch: 102 || EpochTime: 0m21s
# 	Train Loss: 0.191 || Train Acc: 93.37%
# 	 Val Loss: 0.273 ||  Val Acc: 92.27%
# Epoch: 103 || EpochTime: 0m21s
# 	Train Loss: 0.188 || Train Acc: 93.61%
# 	 Val Loss: 0.275 ||  Val Acc: 92.11%
# Epoch: 104 || EpochTime: 0m21s
# 	Train Loss: 0.183 || Train Acc: 93.69%
# 	 Val Loss: 0.283 ||  Val Acc: 92.11%
# Epoch: 105 || EpochTime: 0m21s
# 	Train Loss: 0.190 || Train Acc: 93.43%
# 	 Val Loss: 0.277 ||  Val Acc: 91.77%
# Epoch: 106 || EpochTime: 0m21s
# 	Train Loss: 0.186 || Train Acc: 93.44%
# 	 Val Loss: 0.277 ||  Val Acc: 91.97%
# Epoch: 107 || EpochTime: 0m22s
# 	Train Loss: 0.181 || Train Acc: 93.66%
# 	 Val Loss: 0.269 ||  Val Acc: 92.03%
# Epoch: 108 || EpochTime: 0m21s
# 	Train Loss: 0.181 || Train Acc: 93.81%
# 	 Val Loss: 0.305 ||  Val Acc: 91.36%
# Epoch: 109 || EpochTime: 0m21s
# 	Train Loss: 0.177 || Train Acc: 93.82%
# 	 Val Loss: 0.272 ||  Val Acc: 92.05%
# Epoch: 110 || EpochTime: 0m22s
# 	Train Loss: 0.173 || Train Acc: 94.07%
# 	 Val Loss: 0.274 ||  Val Acc: 92.17%
# Epoch: 111 || EpochTime: 0m21s
# 	Train Loss: 0.173 || Train Acc: 93.93%
# 	 Val Loss: 0.279 ||  Val Acc: 92.35%
# Epoch: 112 || EpochTime: 0m22s
# 	Train Loss: 0.179 || Train Acc: 93.78%
# 	 Val Loss: 0.272 ||  Val Acc: 92.11%
# Epoch: 113 || EpochTime: 0m22s
# 	Train Loss: 0.177 || Train Acc: 93.85%
# 	 Val Loss: 0.267 ||  Val Acc: 92.15%
# Epoch: 114 || EpochTime: 0m21s
# 	Train Loss: 0.175 || Train Acc: 93.98%
# 	 Val Loss: 0.261 ||  Val Acc: 92.66%
# Epoch: 115 || EpochTime: 0m21s
# 	Train Loss: 0.176 || Train Acc: 93.93%
# 	 Val Loss: 0.265 ||  Val Acc: 92.64%
# Epoch: 116 || EpochTime: 0m21s
# 	Train Loss: 0.169 || Train Acc: 94.15%
# 	 Val Loss: 0.265 ||  Val Acc: 92.15%
# Epoch: 117 || EpochTime: 0m22s
# 	Train Loss: 0.174 || Train Acc: 94.08%
# 	 Val Loss: 0.291 ||  Val Acc: 91.97%
# Epoch: 118 || EpochTime: 0m21s
# 	Train Loss: 0.168 || Train Acc: 94.20%
# 	 Val Loss: 0.262 ||  Val Acc: 92.33%
# Epoch: 119 || EpochTime: 0m21s
# 	Train Loss: 0.172 || Train Acc: 94.09%
# 	 Val Loss: 0.271 ||  Val Acc: 92.23%
# Epoch: 120 || EpochTime: 0m22s
# 	Train Loss: 0.170 || Train Acc: 94.14%
# 	 Val Loss: 0.275 ||  Val Acc: 92.15%
# Epoch: 121 || EpochTime: 0m21s
# 	Train Loss: 0.174 || Train Acc: 93.92%
# 	 Val Loss: 0.273 ||  Val Acc: 92.29%
# Epoch: 122 || EpochTime: 0m21s
# 	Train Loss: 0.169 || Train Acc: 94.23%
# 	 Val Loss: 0.270 ||  Val Acc: 92.44%
# Epoch: 123 || EpochTime: 0m21s
# 	Train Loss: 0.167 || Train Acc: 94.18%
# 	 Val Loss: 0.273 ||  Val Acc: 92.37%
# Epoch: 124 || EpochTime: 0m21s
# 	Train Loss: 0.170 || Train Acc: 94.10%
# 	 Val Loss: 0.257 ||  Val Acc: 92.72%
# Epoch: 125 || EpochTime: 0m21s
# 	Train Loss: 0.168 || Train Acc: 94.11%
# 	 Val Loss: 0.265 ||  Val Acc: 92.70%
# Epoch: 126 || EpochTime: 0m21s
# 	Train Loss: 0.162 || Train Acc: 94.43%
# 	 Val Loss: 0.278 ||  Val Acc: 92.70%
# Epoch: 127 || EpochTime: 0m21s
# 	Train Loss: 0.163 || Train Acc: 94.45%
# 	 Val Loss: 0.258 ||  Val Acc: 92.58%
# Epoch: 128 || EpochTime: 0m21s
# 	Train Loss: 0.163 || Train Acc: 94.43%
# 	 Val Loss: 0.266 ||  Val Acc: 92.86%
# Epoch: 129 || EpochTime: 0m21s
# 	Train Loss: 0.158 || Train Acc: 94.52%
# 	 Val Loss: 0.287 ||  Val Acc: 92.39%
# Epoch: 130 || EpochTime: 0m21s
# 	Train Loss: 0.162 || Train Acc: 94.43%
# 	 Val Loss: 0.270 ||  Val Acc: 92.46%
# Epoch: 131 || EpochTime: 0m22s
# 	Train Loss: 0.158 || Train Acc: 94.62%
# 	 Val Loss: 0.290 ||  Val Acc: 92.13%
# Epoch: 132 || EpochTime: 0m21s
# 	Train Loss: 0.167 || Train Acc: 94.33%
# 	 Val Loss: 0.274 ||  Val Acc: 92.25%
# Epoch: 133 || EpochTime: 0m21s
# 	Train Loss: 0.158 || Train Acc: 94.56%
# 	 Val Loss: 0.282 ||  Val Acc: 92.25%
# Epoch: 134 || EpochTime: 0m21s
# 	Train Loss: 0.163 || Train Acc: 94.31%
# 	 Val Loss: 0.272 ||  Val Acc: 92.29%
# Epoch: 135 || EpochTime: 0m21s
# 	Train Loss: 0.163 || Train Acc: 94.34%
# 	 Val Loss: 0.274 ||  Val Acc: 92.31%
# Epoch: 136 || EpochTime: 0m21s
# 	Train Loss: 0.157 || Train Acc: 94.49%
# 	 Val Loss: 0.267 ||  Val Acc: 92.44%
# Epoch: 137 || EpochTime: 0m22s
# 	Train Loss: 0.150 || Train Acc: 94.90%
# 	 Val Loss: 0.263 ||  Val Acc: 92.25%
# Epoch: 138 || EpochTime: 0m21s
# 	Train Loss: 0.158 || Train Acc: 94.55%
# 	 Val Loss: 0.273 ||  Val Acc: 92.37%
# Epoch: 139 || EpochTime: 0m21s
# 	Train Loss: 0.152 || Train Acc: 94.76%
# 	 Val Loss: 0.280 ||  Val Acc: 92.31%
# Epoch: 140 || EpochTime: 0m22s
# 	Train Loss: 0.157 || Train Acc: 94.62%
# 	 Val Loss: 0.265 ||  Val Acc: 92.96%
# Epoch: 141 || EpochTime: 0m21s
# 	Train Loss: 0.152 || Train Acc: 94.68%
# 	 Val Loss: 0.276 ||  Val Acc: 92.39%
# Epoch: 142 || EpochTime: 0m21s
# 	Train Loss: 0.154 || Train Acc: 94.78%
# 	 Val Loss: 0.260 ||  Val Acc: 92.88%
# Epoch: 143 || EpochTime: 0m22s
# 	Train Loss: 0.148 || Train Acc: 94.90%
# 	 Val Loss: 0.262 ||  Val Acc: 92.78%
# Epoch: 144 || EpochTime: 0m22s
# 	Train Loss: 0.151 || Train Acc: 94.86%
# 	 Val Loss: 0.283 ||  Val Acc: 92.44%
# Epoch: 145 || EpochTime: 0m21s
# 	Train Loss: 0.150 || Train Acc: 94.78%
# 	 Val Loss: 0.265 ||  Val Acc: 92.80%
# Epoch: 146 || EpochTime: 0m21s
# 	Train Loss: 0.152 || Train Acc: 94.77%
# 	 Val Loss: 0.290 ||  Val Acc: 92.31%
# Epoch: 147 || EpochTime: 0m21s
# 	Train Loss: 0.153 || Train Acc: 94.79%
# 	 Val Loss: 0.277 ||  Val Acc: 92.78%
# Epoch: 148 || EpochTime: 0m21s
# 	Train Loss: 0.151 || Train Acc: 94.85%
# 	 Val Loss: 0.280 ||  Val Acc: 92.52%
# Epoch: 149 || EpochTime: 0m22s
# 	Train Loss: 0.147 || Train Acc: 95.06%
# 	 Val Loss: 0.277 ||  Val Acc: 92.54%
# Epoch: 150 || EpochTime: 0m22s
# 	Train Loss: 0.155 || Train Acc: 94.72%
# 	 Val Loss: 0.286 ||  Val Acc: 92.46%

# %%
# visualize the loss as the network trained
def get_loss_plot(train_loss, val_loss):
    plt.plot(range(len(train_loss)),train_loss)
    plt.plot(range(len(train_loss)),val_loss)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.title('Loss')
    plt.legend(['Training Loss', 'Validation Loss'])
    plt.savefig('Model.png')
    plt.show()
    
    
# Prints training loss and validation loss 
get_loss_plot(Train_Loss, Val_Loss)

# %% [markdown]
# #5.  Evaluate Best Saved Model on Test Dataset

# %%
# Load saved model's parameters
model.load_state_dict(torch.load('Model.pt'))

# Calculate test loss and accuracy
test_loss, test_acc = evaluate(model, test_dataloader, criterion, device)


print(f'Test Loss: {test_loss:.3f} || Test Acc: {test_acc*100:.2f}%')
# Out:
# Test Loss: 0.245 || Test Acc: 92.62%
