# %%
import torch, torchvision
import torchvision.transforms as transforms
import torch.nn as nn, torch.nn.functional as F
import torch.optim as optim, torch.utils.data as data
import torchvision.datasets as datasets
import time, copy, random, os, numpy as np
import matplotlib.pyplot as plt
from torchvision.transforms.autoaugment import AutoAugmentPolicy
from torch.optim.lr_scheduler import ReduceLROnPlateau, OneCycleLR
from torch.utils.data import random_split
from torchsummary import summary

# %%
BATCH_SIZE = 64
INPUT_SIZE = (3, 32, 32)
EPOCHS = 150
LEARNING_RATE = 1e-3

# %%
#Verify GPU
# !nvidia-smi
# Out:
# Mon Apr 10 12:24:05 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0    52W / 400W |   1837MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# Specify device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Sets the seed for numpy and torch to make sure functions with a random component behave deterministically
# torch.backends.cudnn.deterministic = true sets the CuDNN to deterministic mode.
# This function allows us to run experiments 100% deterministically.
# https://gist.github.com/ihoromi4/b681a9088f348942b01711f251e5f964

def seed_everything(seed=1234):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything()

# %% [markdown]
# # 1.  Load and Batch the Data

# %%
def get_data_loaders(batch_size, root = '.data', valid_ratio = 0.1):
  
    #means and stds for the 3 channels of the dataset
    means = (0.4914, 0.4822, 0.4465)
    stds = (0.2023, 0.1994, 0.2010)

    #   Performs the following data augmentations on the training set:
    #       1.  Random Rotation:  
    #       2.  RandomHorizontalFlip
    #       3.  Random Crop
    #       4.  AutoAugment: AutoAugmention policies learned from the CIFAR10 dataset
    #           AutoAugment: Learning Augmentation Strategies from Data" <https://arxiv.org/pdf/1805.09501.pdf>`
    train_transforms = transforms.Compose([
                           transforms.RandomRotation(5),
                           transforms.RandomHorizontalFlip(0.5),
                           transforms.RandomCrop(32, padding = 2),
                           transforms.AutoAugment(AutoAugmentPolicy.CIFAR10),
                           transforms.ToTensor(),  # convert data to torch.FloatTensor: CxHxW
                           transforms.Normalize(mean = means, std = stds, inplace=True), #Range is in [-1,1], data = (data - mean)/std
                       ])

    test_transforms = transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize(mean = means, std = stds, inplace=True),
                       ])

    # choose the training and test datasets
    train_data = datasets.CIFAR10(root, 
                              train = True, 
                              download = True, 
                              transform = train_transforms)
    
    test_data = datasets.CIFAR10(root, 
                             train = False, 
                             download = True, 
                             transform = test_transforms)
    
    # obtain number of training/validation examples that will be used to create the respective datasets 
    n_train_examples = int((1 - valid_ratio) * len(train_data))
    n_valid_examples = int(valid_ratio* len(train_data))

    train_data, valid_data = random_split(train_data, [n_train_examples, n_valid_examples])
    
    #Creates a deep copy
    valid_data = copy.deepcopy(valid_data)  
    valid_data.dataset.transform = test_transforms

    # load training data in batches
    train_dataloader = data.DataLoader(train_data,
                                 shuffle = True,
                                 batch_size = batch_size,
                                 num_workers=2, 
                                 pin_memory=True)   #pin_memory speeds transfer of data from CPU to GPU

    # load validation data in batches
    valid_dataloader = data.DataLoader(valid_data,
                                 batch_size = batch_size,
                                 num_workers=2, 
                                 pin_memory=True)

    # load test data in batches
    test_dataloader = data.DataLoader(test_data,
                                batch_size = batch_size,
                                num_workers=2, 
                                pin_memory=True)
  
    return train_dataloader, valid_dataloader, test_dataloader

# %%
# Load and batch the data
train_dataloader, valid_dataloader, test_dataloader = get_data_loaders(BATCH_SIZE)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # 2.  Define the Network

# %%
'''ResNet in PyTorch.
For Pre-activation ResNet, see 'preact_resnet.py'.
Reference:
[1] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun
    Deep Residual Learning for Image Recognition. arXiv:1512.03385
'''

#Residual Block
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

#1. Convolutional Layer: conv1
#2. Residual Layers: layer1, layer2, layer3, layer4
#3. Fully Connected Layer: linear
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 32

        self.conv1 = nn.Conv2d(3, 32, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        self.layer1 = self._make_layer(block, 32, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 64, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 128, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 256, num_blocks[3], stride=2)
        self.layer5 = self._make_layer(block, 512, num_blocks[4], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        #out = F.avg_pool2d(out, 4)
        out = F.avg_pool2d(out, 2)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

#ResNet18 has 4 residual layers, each composed of a specifed number of residual blocks
def ResNet18():
    return ResNet(BasicBlock, [2,2,1,1,1])

# %% [markdown]
# # 3.  Specify Model, Loss Function, Optimizer, and Scheduler

# %%
# Specify the model, loss function, and optimizer; move model to device
model = ResNet18().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# Specify scheduler
scheduler = ReduceLROnPlateau(optimizer, 'min')

# %%
# Check total number of parameters
summary(model, input_size=INPUT_SIZE)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#             Conv2d-3           [-1, 32, 32, 32]           9,216
#        BatchNorm2d-4           [-1, 32, 32, 32]              64
#             Conv2d-5           [-1, 32, 32, 32]           9,216
#        BatchNorm2d-6           [-1, 32, 32, 32]              64
#         BasicBlock-7           [-1, 32, 32, 32]               0
#             Conv2d-8           [-1, 32, 32, 32]           9,216
#        BatchNorm2d-9           [-1, 32, 32, 32]              64
#            Conv2d-10           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-11           [-1, 32, 32, 32]              64
#        BasicBlock-12           [-1, 32, 32, 32]               0
#            Conv2d-13           [-1, 64, 16, 16]          18,432
#       BatchNorm2d-14           [-1, 64, 16, 16]             128
#            Conv2d-15           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-16           [-1, 64, 16, 16]             128
#            Conv2d-17           [-1, 64, 16, 16]           2,048
#       BatchNorm2d-18           [-1, 64, 16, 16]             128
#        BasicBlock-19           [-1, 64, 16, 16]               0
#            Conv2d-20           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-21           [-1, 64, 16, 16]             128
#            Conv2d-22           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-23           [-1, 64, 16, 16]             128
#        BasicBlock-24           [-1, 64, 16, 16]               0
#            Conv2d-25            [-1, 128, 8, 8]          73,728
#       BatchNorm2d-26            [-1, 128, 8, 8]             256
#            Conv2d-27            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-28            [-1, 128, 8, 8]             256
#            Conv2d-29            [-1, 128, 8, 8]           8,192
#       BatchNorm2d-30            [-1, 128, 8, 8]             256
#        BasicBlock-31            [-1, 128, 8, 8]               0
#            Conv2d-32            [-1, 256, 4, 4]         294,912
#       BatchNorm2d-33            [-1, 256, 4, 4]             512
#            Conv2d-34            [-1, 256, 4, 4]         589,824
#       BatchNorm2d-35            [-1, 256, 4, 4]             512
#            Conv2d-36            [-1, 256, 4, 4]          32,768
#       BatchNorm2d-37            [-1, 256, 4, 4]             512
#        BasicBlock-38            [-1, 256, 4, 4]               0
#            Conv2d-39            [-1, 512, 2, 2]       1,179,648
#       BatchNorm2d-40            [-1, 512, 2, 2]           1,024
#            Conv2d-41            [-1, 512, 2, 2]       2,359,296
#       BatchNorm2d-42            [-1, 512, 2, 2]           1,024
#            Conv2d-43            [-1, 512, 2, 2]         131,072
#       BatchNorm2d-44            [-1, 512, 2, 2]           1,024
#        BasicBlock-45            [-1, 512, 2, 2]               0
#            Linear-46                   [-1, 10]           5,130
# ================================================================
# Total params: 4,997,162
# Trainable params: 4,997,162
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.27
# Params size (MB): 19.06
# Estimated Total Size (MB): 24.34
# ----------------------------------------------------------------

# %% [markdown]
# #4. Training and Validation

# %%
# accuracy is the fraction of predictions the model got correct
def calculate_accuracy(y_pred, y):
    top_pred = y_pred.argmax(1, keepdim = True)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    acc = correct.float() / y.shape[0]
    return acc

# time interval for each epoch
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
def train(model, iterator, optimizer, criterion, device):
    
    # Tracks training loss and accuracy as model trains
    epoch_loss = 0
    epoch_acc = 0
    #lrs = []

    # Prep model for training
    model.train()

    for (x, y) in iterator:
        # Move inputs and labels to device
        x = x.to(device)
        y = y.to(device)
        
        # Clear the gradients of all optimized variables
        optimizer.zero_grad()

        # Forward pass: compute predicted outputs by passing inputs to the model        
        y_pred = model(x)
        
        # Calculate the loss
        loss = criterion(y_pred, y)
        
        # Calculate the accuracy
        acc = calculate_accuracy(y_pred, y)
        
        # Backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()

        #OneCycleLr Scheduler
        #scheduler.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def evaluate(model, iterator, criterion, device):
    # Keeps track of validation loss and  accuracy
    epoch_loss = 0
    epoch_acc = 0
    
    # Prep model for evaluation
    model.eval()
    
    with torch.no_grad():
        
        for (x, y) in iterator:

            x = x.to(device)
            y = y.to(device)

            # Forward Pass
            y_pred = model(x)
            # Calculate the validation loss
            loss = criterion(y_pred, y)
            #Calculate the validation accuracy
            acc = calculate_accuracy(y_pred, y)

            #Record validation loss
            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
# Train and Validate the model:

# Tracks average training loss and accuracy per epoch
#  and tracks average validation loss and accuracy per epoch
Train_Loss = []
Train_Acc = []
Val_Loss = []
Val_Acc = []


# Tracks best validation loss
best_valid_loss = float('inf')
for epoch in range(EPOCHS):
    # Epoch start time
    start_time = time.monotonic()


    train_loss, train_acc = train(model, train_dataloader, optimizer, criterion, device)
    valid_loss, valid_acc = evaluate(model, valid_dataloader, criterion, device)
  

    # OnReducePlateau is a scheduler monitoring validation loss
    scheduler.step(valid_loss)

    # Saves model with best validation loss in a state dictionary
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(),'Model_1.pt')
    # Epoch end time
    end_time = time.monotonic()

    # Prints training/validation statistics as well as epoch time
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    print(f'Epoch: {epoch+1:02} || EpochTime: {epoch_mins}m{epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} || Train Acc: {train_acc*100:.2f}%')
    print(f'\t Val Loss: {valid_loss:.3f} ||  Val Acc: {valid_acc*100:.2f}%')

    Train_Loss.append(train_loss)
    Train_Acc.append(train_acc)
    Val_Loss.append(valid_loss)
    Val_Acc.append(valid_acc)
# Out:
# Epoch: 01 || EpochTime: 0m22s
# 	Train Loss: 1.698 || Train Acc: 38.05%
# 	 Val Loss: 1.418 ||  Val Acc: 50.61%
# Epoch: 02 || EpochTime: 0m21s
# 	Train Loss: 1.263 || Train Acc: 54.65%
# 	 Val Loss: 0.976 ||  Val Acc: 64.60%
# Epoch: 03 || EpochTime: 0m21s
# 	Train Loss: 1.065 || Train Acc: 62.23%
# 	 Val Loss: 0.749 ||  Val Acc: 73.81%
# Epoch: 04 || EpochTime: 0m21s
# 	Train Loss: 0.938 || Train Acc: 67.07%
# 	 Val Loss: 0.658 ||  Val Acc: 77.10%
# Epoch: 05 || EpochTime: 0m21s
# 	Train Loss: 0.855 || Train Acc: 70.08%
# 	 Val Loss: 0.609 ||  Val Acc: 79.51%
# Epoch: 06 || EpochTime: 0m21s
# 	Train Loss: 0.786 || Train Acc: 72.42%
# 	 Val Loss: 0.576 ||  Val Acc: 79.85%
# Epoch: 07 || EpochTime: 0m21s
# 	Train Loss: 0.738 || Train Acc: 74.35%
# 	 Val Loss: 0.530 ||  Val Acc: 82.16%
# Epoch: 08 || EpochTime: 0m21s
# 	Train Loss: 0.697 || Train Acc: 75.77%
# 	 Val Loss: 0.498 ||  Val Acc: 83.33%
# Epoch: 09 || EpochTime: 0m21s
# 	Train Loss: 0.662 || Train Acc: 76.66%
# 	 Val Loss: 0.461 ||  Val Acc: 83.98%
# Epoch: 10 || EpochTime: 0m21s
# 	Train Loss: 0.627 || Train Acc: 78.17%
# 	 Val Loss: 0.547 ||  Val Acc: 81.01%
# Epoch: 11 || EpochTime: 0m21s
# 	Train Loss: 0.601 || Train Acc: 79.21%
# 	 Val Loss: 0.429 ||  Val Acc: 85.34%
# Epoch: 12 || EpochTime: 0m21s
# 	Train Loss: 0.575 || Train Acc: 79.95%
# 	 Val Loss: 0.443 ||  Val Acc: 85.36%
# Epoch: 13 || EpochTime: 0m21s
# 	Train Loss: 0.554 || Train Acc: 80.54%
# 	 Val Loss: 0.437 ||  Val Acc: 85.54%
# Epoch: 14 || EpochTime: 0m22s
# 	Train Loss: 0.534 || Train Acc: 81.27%
# 	 Val Loss: 0.410 ||  Val Acc: 86.53%
# Epoch: 15 || EpochTime: 0m21s
# 	Train Loss: 0.521 || Train Acc: 81.80%
# 	 Val Loss: 0.392 ||  Val Acc: 86.25%
# Epoch: 16 || EpochTime: 0m21s
# 	Train Loss: 0.502 || Train Acc: 82.52%
# 	 Val Loss: 0.377 ||  Val Acc: 87.32%
# Epoch: 17 || EpochTime: 0m21s
# 	Train Loss: 0.483 || Train Acc: 83.15%
# 	 Val Loss: 0.382 ||  Val Acc: 87.42%
# Epoch: 18 || EpochTime: 0m21s
# 	Train Loss: 0.473 || Train Acc: 83.45%
# 	 Val Loss: 0.388 ||  Val Acc: 87.06%
# Epoch: 19 || EpochTime: 0m21s
# 	Train Loss: 0.467 || Train Acc: 83.51%
# 	 Val Loss: 0.370 ||  Val Acc: 87.72%
# Epoch: 20 || EpochTime: 0m21s
# 	Train Loss: 0.452 || Train Acc: 84.03%
# 	 Val Loss: 0.364 ||  Val Acc: 88.03%
# Epoch: 21 || EpochTime: 0m22s
# 	Train Loss: 0.431 || Train Acc: 84.98%
# 	 Val Loss: 0.362 ||  Val Acc: 88.31%
# Epoch: 22 || EpochTime: 0m21s
# 	Train Loss: 0.427 || Train Acc: 85.16%
# 	 Val Loss: 0.367 ||  Val Acc: 87.80%
# Epoch: 23 || EpochTime: 0m21s
# 	Train Loss: 0.415 || Train Acc: 85.55%
# 	 Val Loss: 0.347 ||  Val Acc: 88.65%
# Epoch: 24 || EpochTime: 0m21s
# 	Train Loss: 0.402 || Train Acc: 85.89%
# 	 Val Loss: 0.339 ||  Val Acc: 88.65%
# Epoch: 25 || EpochTime: 0m21s
# 	Train Loss: 0.393 || Train Acc: 86.25%
# 	 Val Loss: 0.344 ||  Val Acc: 88.75%
# Epoch: 26 || EpochTime: 0m21s
# 	Train Loss: 0.386 || Train Acc: 86.66%
# 	 Val Loss: 0.361 ||  Val Acc: 88.17%
# Epoch: 27 || EpochTime: 0m21s
# 	Train Loss: 0.375 || Train Acc: 86.87%
# 	 Val Loss: 0.339 ||  Val Acc: 89.38%
# Epoch: 28 || EpochTime: 0m21s
# 	Train Loss: 0.368 || Train Acc: 87.24%
# 	 Val Loss: 0.346 ||  Val Acc: 88.07%
# Epoch: 29 || EpochTime: 0m21s
# 	Train Loss: 0.366 || Train Acc: 87.20%
# 	 Val Loss: 0.339 ||  Val Acc: 88.69%
# Epoch: 30 || EpochTime: 0m21s
# 	Train Loss: 0.352 || Train Acc: 87.65%
# 	 Val Loss: 0.333 ||  Val Acc: 89.56%
# Epoch: 31 || EpochTime: 0m21s
# 	Train Loss: 0.357 || Train Acc: 87.57%
# 	 Val Loss: 0.331 ||  Val Acc: 89.06%
# Epoch: 32 || EpochTime: 0m21s
# 	Train Loss: 0.342 || Train Acc: 88.15%
# 	 Val Loss: 0.326 ||  Val Acc: 89.52%
# Epoch: 33 || EpochTime: 0m21s
# 	Train Loss: 0.331 || Train Acc: 88.47%
# 	 Val Loss: 0.333 ||  Val Acc: 89.26%
# Epoch: 34 || EpochTime: 0m21s
# 	Train Loss: 0.327 || Train Acc: 88.57%
# 	 Val Loss: 0.341 ||  Val Acc: 89.04%
# Epoch: 35 || EpochTime: 0m21s
# 	Train Loss: 0.322 || Train Acc: 88.68%
# 	 Val Loss: 0.311 ||  Val Acc: 89.99%
# Epoch: 36 || EpochTime: 0m20s
# 	Train Loss: 0.316 || Train Acc: 88.94%
# 	 Val Loss: 0.360 ||  Val Acc: 89.64%
# Epoch: 37 || EpochTime: 0m22s
# 	Train Loss: 0.318 || Train Acc: 88.82%
# 	 Val Loss: 0.335 ||  Val Acc: 89.38%
# Epoch: 38 || EpochTime: 0m21s
# 	Train Loss: 0.308 || Train Acc: 89.12%
# 	 Val Loss: 0.303 ||  Val Acc: 90.80%
# Epoch: 39 || EpochTime: 0m21s
# 	Train Loss: 0.303 || Train Acc: 89.50%
# 	 Val Loss: 0.314 ||  Val Acc: 90.11%
# Epoch: 40 || EpochTime: 0m21s
# 	Train Loss: 0.301 || Train Acc: 89.54%
# 	 Val Loss: 0.313 ||  Val Acc: 90.72%
# Epoch: 41 || EpochTime: 0m21s
# 	Train Loss: 0.294 || Train Acc: 89.73%
# 	 Val Loss: 0.329 ||  Val Acc: 90.19%
# Epoch: 42 || EpochTime: 0m21s
# 	Train Loss: 0.290 || Train Acc: 89.77%
# 	 Val Loss: 0.349 ||  Val Acc: 89.56%
# Epoch: 43 || EpochTime: 0m21s
# 	Train Loss: 0.286 || Train Acc: 90.07%
# 	 Val Loss: 0.328 ||  Val Acc: 89.99%
# Epoch: 44 || EpochTime: 0m21s
# 	Train Loss: 0.281 || Train Acc: 90.05%
# 	 Val Loss: 0.328 ||  Val Acc: 90.37%
# Epoch: 45 || EpochTime: 0m21s
# 	Train Loss: 0.272 || Train Acc: 90.46%
# 	 Val Loss: 0.364 ||  Val Acc: 89.26%
# Epoch: 46 || EpochTime: 0m21s
# 	Train Loss: 0.278 || Train Acc: 90.25%
# 	 Val Loss: 0.367 ||  Val Acc: 89.26%
# Epoch: 47 || EpochTime: 0m21s
# 	Train Loss: 0.276 || Train Acc: 90.34%
# 	 Val Loss: 0.325 ||  Val Acc: 90.23%
# Epoch: 48 || EpochTime: 0m21s
# 	Train Loss: 0.269 || Train Acc: 90.64%
# 	 Val Loss: 0.318 ||  Val Acc: 90.53%
# Epoch: 49 || EpochTime: 0m21s
# 	Train Loss: 0.261 || Train Acc: 90.99%
# 	 Val Loss: 0.338 ||  Val Acc: 90.13%
# Epoch: 50 || EpochTime: 0m21s
# 	Train Loss: 0.225 || Train Acc: 92.13%
# 	 Val Loss: 0.304 ||  Val Acc: 91.28%
# Epoch: 51 || EpochTime: 0m21s
# 	Train Loss: 0.207 || Train Acc: 92.89%
# 	 Val Loss: 0.298 ||  Val Acc: 91.30%
# Epoch: 52 || EpochTime: 0m21s
# 	Train Loss: 0.199 || Train Acc: 93.17%
# 	 Val Loss: 0.297 ||  Val Acc: 91.53%
# Epoch: 53 || EpochTime: 0m21s
# 	Train Loss: 0.195 || Train Acc: 93.39%
# 	 Val Loss: 0.293 ||  Val Acc: 91.48%
# Epoch: 54 || EpochTime: 0m21s
# 	Train Loss: 0.193 || Train Acc: 93.32%
# 	 Val Loss: 0.296 ||  Val Acc: 91.42%
# Epoch: 55 || EpochTime: 0m22s
# 	Train Loss: 0.187 || Train Acc: 93.60%
# 	 Val Loss: 0.296 ||  Val Acc: 91.57%
# Epoch: 56 || EpochTime: 0m21s
# 	Train Loss: 0.191 || Train Acc: 93.51%
# 	 Val Loss: 0.302 ||  Val Acc: 91.55%
# Epoch: 57 || EpochTime: 0m21s
# 	Train Loss: 0.184 || Train Acc: 93.66%
# 	 Val Loss: 0.301 ||  Val Acc: 91.57%
# Epoch: 58 || EpochTime: 0m21s
# 	Train Loss: 0.182 || Train Acc: 93.66%
# 	 Val Loss: 0.299 ||  Val Acc: 91.63%
# Epoch: 59 || EpochTime: 0m21s
# 	Train Loss: 0.186 || Train Acc: 93.63%
# 	 Val Loss: 0.296 ||  Val Acc: 91.65%
# Epoch: 60 || EpochTime: 0m21s
# 	Train Loss: 0.181 || Train Acc: 93.81%
# 	 Val Loss: 0.283 ||  Val Acc: 91.77%
# Epoch: 61 || EpochTime: 0m21s
# 	Train Loss: 0.177 || Train Acc: 93.83%
# 	 Val Loss: 0.291 ||  Val Acc: 91.87%
# Epoch: 62 || EpochTime: 0m21s
# 	Train Loss: 0.181 || Train Acc: 93.71%
# 	 Val Loss: 0.289 ||  Val Acc: 91.73%
# Epoch: 63 || EpochTime: 0m21s
# 	Train Loss: 0.174 || Train Acc: 94.00%
# 	 Val Loss: 0.284 ||  Val Acc: 91.85%
# Epoch: 64 || EpochTime: 0m21s
# 	Train Loss: 0.173 || Train Acc: 93.98%
# 	 Val Loss: 0.291 ||  Val Acc: 91.50%
# Epoch: 65 || EpochTime: 0m21s
# 	Train Loss: 0.172 || Train Acc: 94.12%
# 	 Val Loss: 0.288 ||  Val Acc: 92.19%
# Epoch: 66 || EpochTime: 0m21s
# 	Train Loss: 0.173 || Train Acc: 94.19%
# 	 Val Loss: 0.291 ||  Val Acc: 91.75%
# Epoch: 67 || EpochTime: 0m21s
# 	Train Loss: 0.171 || Train Acc: 94.01%
# 	 Val Loss: 0.291 ||  Val Acc: 91.89%
# Epoch: 68 || EpochTime: 0m21s
# 	Train Loss: 0.168 || Train Acc: 94.12%
# 	 Val Loss: 0.292 ||  Val Acc: 91.87%
# Epoch: 69 || EpochTime: 0m22s
# 	Train Loss: 0.171 || Train Acc: 94.22%
# 	 Val Loss: 0.300 ||  Val Acc: 91.79%
# Epoch: 70 || EpochTime: 0m21s
# 	Train Loss: 0.171 || Train Acc: 94.12%
# 	 Val Loss: 0.300 ||  Val Acc: 91.85%
# Epoch: 71 || EpochTime: 0m21s
# 	Train Loss: 0.168 || Train Acc: 94.18%
# 	 Val Loss: 0.292 ||  Val Acc: 91.93%
# Epoch: 72 || EpochTime: 0m21s
# 	Train Loss: 0.164 || Train Acc: 94.33%
# 	 Val Loss: 0.293 ||  Val Acc: 91.99%
# Epoch: 73 || EpochTime: 0m21s
# 	Train Loss: 0.161 || Train Acc: 94.57%
# 	 Val Loss: 0.294 ||  Val Acc: 91.99%
# Epoch: 74 || EpochTime: 0m21s
# 	Train Loss: 0.164 || Train Acc: 94.26%
# 	 Val Loss: 0.295 ||  Val Acc: 91.95%
# Epoch: 75 || EpochTime: 0m21s
# 	Train Loss: 0.159 || Train Acc: 94.58%
# 	 Val Loss: 0.293 ||  Val Acc: 92.05%
# Epoch: 76 || EpochTime: 0m21s
# 	Train Loss: 0.162 || Train Acc: 94.58%
# 	 Val Loss: 0.293 ||  Val Acc: 91.93%
# Epoch: 77 || EpochTime: 0m21s
# 	Train Loss: 0.168 || Train Acc: 94.24%
# 	 Val Loss: 0.292 ||  Val Acc: 91.97%
# Epoch: 78 || EpochTime: 0m22s
# 	Train Loss: 0.160 || Train Acc: 94.50%
# 	 Val Loss: 0.292 ||  Val Acc: 91.91%
# Epoch: 79 || EpochTime: 0m21s
# 	Train Loss: 0.161 || Train Acc: 94.41%
# 	 Val Loss: 0.294 ||  Val Acc: 91.91%
# Epoch: 80 || EpochTime: 0m21s
# 	Train Loss: 0.157 || Train Acc: 94.66%
# 	 Val Loss: 0.294 ||  Val Acc: 92.01%
# Epoch: 81 || EpochTime: 0m22s
# 	Train Loss: 0.160 || Train Acc: 94.50%
# 	 Val Loss: 0.289 ||  Val Acc: 92.15%
# Epoch: 82 || EpochTime: 0m21s
# 	Train Loss: 0.164 || Train Acc: 94.37%
# 	 Val Loss: 0.290 ||  Val Acc: 92.27%
# Epoch: 83 || EpochTime: 0m21s
# 	Train Loss: 0.162 || Train Acc: 94.54%
# 	 Val Loss: 0.299 ||  Val Acc: 92.07%
# Epoch: 84 || EpochTime: 0m21s
# 	Train Loss: 0.159 || Train Acc: 94.59%
# 	 Val Loss: 0.291 ||  Val Acc: 92.05%
# Epoch: 85 || EpochTime: 0m22s
# 	Train Loss: 0.161 || Train Acc: 94.38%
# 	 Val Loss: 0.294 ||  Val Acc: 91.95%
# Epoch: 86 || EpochTime: 0m21s
# 	Train Loss: 0.163 || Train Acc: 94.46%
# 	 Val Loss: 0.293 ||  Val Acc: 92.01%
# Epoch: 87 || EpochTime: 0m21s
# 	Train Loss: 0.163 || Train Acc: 94.40%
# 	 Val Loss: 0.291 ||  Val Acc: 92.07%
# Epoch: 88 || EpochTime: 0m21s
# 	Train Loss: 0.157 || Train Acc: 94.60%
# 	 Val Loss: 0.290 ||  Val Acc: 92.03%
# Epoch: 89 || EpochTime: 0m21s
# 	Train Loss: 0.160 || Train Acc: 94.50%
# 	 Val Loss: 0.295 ||  Val Acc: 92.09%
# Epoch: 90 || EpochTime: 0m22s
# 	Train Loss: 0.161 || Train Acc: 94.56%
# 	 Val Loss: 0.293 ||  Val Acc: 91.97%
# Epoch: 91 || EpochTime: 0m21s
# 	Train Loss: 0.165 || Train Acc: 94.34%
# 	 Val Loss: 0.292 ||  Val Acc: 92.11%
# Epoch: 92 || EpochTime: 0m21s
# 	Train Loss: 0.161 || Train Acc: 94.48%
# 	 Val Loss: 0.292 ||  Val Acc: 91.99%
# Epoch: 93 || EpochTime: 0m21s
# 	Train Loss: 0.160 || Train Acc: 94.42%
# 	 Val Loss: 0.290 ||  Val Acc: 91.99%
# Epoch: 94 || EpochTime: 0m21s
# 	Train Loss: 0.157 || Train Acc: 94.58%
# 	 Val Loss: 0.295 ||  Val Acc: 91.91%
# Epoch: 95 || EpochTime: 0m21s
# 	Train Loss: 0.159 || Train Acc: 94.52%
# 	 Val Loss: 0.295 ||  Val Acc: 91.87%
# Epoch: 96 || EpochTime: 0m22s
# 	Train Loss: 0.159 || Train Acc: 94.66%
# 	 Val Loss: 0.289 ||  Val Acc: 92.11%
# Epoch: 97 || EpochTime: 0m21s
# 	Train Loss: 0.161 || Train Acc: 94.46%
# 	 Val Loss: 0.289 ||  Val Acc: 92.05%
# Epoch: 98 || EpochTime: 0m21s
# 	Train Loss: 0.157 || Train Acc: 94.62%
# 	 Val Loss: 0.295 ||  Val Acc: 92.11%
# Epoch: 99 || EpochTime: 0m21s
# 	Train Loss: 0.161 || Train Acc: 94.58%
# 	 Val Loss: 0.294 ||  Val Acc: 92.01%
# Epoch: 100 || EpochTime: 0m22s
# 	Train Loss: 0.158 || Train Acc: 94.64%
# 	 Val Loss: 0.293 ||  Val Acc: 91.93%
# Epoch: 101 || EpochTime: 0m21s
# 	Train Loss: 0.157 || Train Acc: 94.62%
# 	 Val Loss: 0.296 ||  Val Acc: 92.05%
# Epoch: 102 || EpochTime: 0m22s
# 	Train Loss: 0.156 || Train Acc: 94.65%
# 	 Val Loss: 0.297 ||  Val Acc: 91.93%
# Epoch: 103 || EpochTime: 0m21s
# 	Train Loss: 0.159 || Train Acc: 94.52%
# 	 Val Loss: 0.292 ||  Val Acc: 92.07%
# Epoch: 104 || EpochTime: 0m22s
# 	Train Loss: 0.161 || Train Acc: 94.44%
# 	 Val Loss: 0.297 ||  Val Acc: 91.83%
# Epoch: 105 || EpochTime: 0m21s
# 	Train Loss: 0.160 || Train Acc: 94.50%
# 	 Val Loss: 0.291 ||  Val Acc: 92.01%
# Epoch: 106 || EpochTime: 0m21s
# 	Train Loss: 0.161 || Train Acc: 94.52%
# 	 Val Loss: 0.290 ||  Val Acc: 91.97%
# Epoch: 107 || EpochTime: 0m21s
# 	Train Loss: 0.161 || Train Acc: 94.44%
# 	 Val Loss: 0.291 ||  Val Acc: 92.03%
# Epoch: 108 || EpochTime: 0m21s
# 	Train Loss: 0.154 || Train Acc: 94.83%
# 	 Val Loss: 0.287 ||  Val Acc: 91.99%
# Epoch: 109 || EpochTime: 0m22s
# 	Train Loss: 0.161 || Train Acc: 94.53%
# 	 Val Loss: 0.289 ||  Val Acc: 92.21%
# Epoch: 110 || EpochTime: 0m22s
# 	Train Loss: 0.157 || Train Acc: 94.57%
# 	 Val Loss: 0.289 ||  Val Acc: 92.11%
# Epoch: 111 || EpochTime: 0m21s
# 	Train Loss: 0.164 || Train Acc: 94.36%
# 	 Val Loss: 0.293 ||  Val Acc: 92.17%
# Epoch: 112 || EpochTime: 0m21s
# 	Train Loss: 0.159 || Train Acc: 94.64%
# 	 Val Loss: 0.295 ||  Val Acc: 91.97%
# Epoch: 113 || EpochTime: 0m21s
# 	Train Loss: 0.158 || Train Acc: 94.64%
# 	 Val Loss: 0.294 ||  Val Acc: 92.09%
# Epoch: 114 || EpochTime: 0m21s
# 	Train Loss: 0.163 || Train Acc: 94.32%
# 	 Val Loss: 0.298 ||  Val Acc: 91.95%
# Epoch: 115 || EpochTime: 0m21s
# 	Train Loss: 0.157 || Train Acc: 94.64%
# 	 Val Loss: 0.290 ||  Val Acc: 92.03%
# Epoch: 116 || EpochTime: 0m21s
# 	Train Loss: 0.160 || Train Acc: 94.46%
# 	 Val Loss: 0.289 ||  Val Acc: 91.95%
# Epoch: 117 || EpochTime: 0m21s
# 	Train Loss: 0.157 || Train Acc: 94.62%
# 	 Val Loss: 0.288 ||  Val Acc: 92.01%
# Epoch: 118 || EpochTime: 0m21s
# 	Train Loss: 0.164 || Train Acc: 94.53%
# 	 Val Loss: 0.291 ||  Val Acc: 92.17%
# Epoch: 119 || EpochTime: 0m21s
# 	Train Loss: 0.159 || Train Acc: 94.50%
# 	 Val Loss: 0.292 ||  Val Acc: 92.05%
# Epoch: 120 || EpochTime: 0m21s
# 	Train Loss: 0.160 || Train Acc: 94.49%
# 	 Val Loss: 0.292 ||  Val Acc: 91.89%
# Epoch: 121 || EpochTime: 0m21s
# 	Train Loss: 0.164 || Train Acc: 94.30%
# 	 Val Loss: 0.286 ||  Val Acc: 91.93%
# Epoch: 122 || EpochTime: 0m22s
# 	Train Loss: 0.162 || Train Acc: 94.41%
# 	 Val Loss: 0.289 ||  Val Acc: 92.17%
# Epoch: 123 || EpochTime: 0m21s
# 	Train Loss: 0.161 || Train Acc: 94.41%
# 	 Val Loss: 0.291 ||  Val Acc: 91.97%
# Epoch: 124 || EpochTime: 0m21s
# 	Train Loss: 0.157 || Train Acc: 94.61%
# 	 Val Loss: 0.294 ||  Val Acc: 92.03%
# Epoch: 125 || EpochTime: 0m21s
# 	Train Loss: 0.161 || Train Acc: 94.54%
# 	 Val Loss: 0.293 ||  Val Acc: 91.87%
# Epoch: 126 || EpochTime: 0m21s
# 	Train Loss: 0.160 || Train Acc: 94.58%
# 	 Val Loss: 0.289 ||  Val Acc: 92.05%
# Epoch: 127 || EpochTime: 0m21s
# 	Train Loss: 0.159 || Train Acc: 94.49%
# 	 Val Loss: 0.292 ||  Val Acc: 92.09%
# Epoch: 128 || EpochTime: 0m22s
# 	Train Loss: 0.160 || Train Acc: 94.51%
# 	 Val Loss: 0.289 ||  Val Acc: 92.01%
# Epoch: 129 || EpochTime: 0m21s
# 	Train Loss: 0.165 || Train Acc: 94.38%
# 	 Val Loss: 0.291 ||  Val Acc: 92.03%
# Epoch: 130 || EpochTime: 0m21s
# 	Train Loss: 0.161 || Train Acc: 94.45%
# 	 Val Loss: 0.292 ||  Val Acc: 92.13%
# Epoch: 131 || EpochTime: 0m21s
# 	Train Loss: 0.164 || Train Acc: 94.51%
# 	 Val Loss: 0.291 ||  Val Acc: 92.03%
# Epoch: 132 || EpochTime: 0m21s
# 	Train Loss: 0.153 || Train Acc: 94.79%
# 	 Val Loss: 0.285 ||  Val Acc: 92.09%
# Epoch: 133 || EpochTime: 0m21s
# 	Train Loss: 0.154 || Train Acc: 94.74%
# 	 Val Loss: 0.294 ||  Val Acc: 91.95%
# Epoch: 134 || EpochTime: 0m22s
# 	Train Loss: 0.163 || Train Acc: 94.43%
# 	 Val Loss: 0.290 ||  Val Acc: 91.99%
# Epoch: 135 || EpochTime: 0m22s
# 	Train Loss: 0.160 || Train Acc: 94.38%
# 	 Val Loss: 0.297 ||  Val Acc: 91.91%
# Epoch: 136 || EpochTime: 0m21s
# 	Train Loss: 0.161 || Train Acc: 94.45%
# 	 Val Loss: 0.294 ||  Val Acc: 91.85%
# Epoch: 137 || EpochTime: 0m21s
# 	Train Loss: 0.156 || Train Acc: 94.58%
# 	 Val Loss: 0.292 ||  Val Acc: 91.97%
# Epoch: 138 || EpochTime: 0m21s
# 	Train Loss: 0.156 || Train Acc: 94.62%
# 	 Val Loss: 0.287 ||  Val Acc: 92.13%
# Epoch: 139 || EpochTime: 0m21s
# 	Train Loss: 0.158 || Train Acc: 94.60%
# 	 Val Loss: 0.296 ||  Val Acc: 92.01%
# Epoch: 140 || EpochTime: 0m21s
# 	Train Loss: 0.159 || Train Acc: 94.46%
# 	 Val Loss: 0.291 ||  Val Acc: 91.89%
# Epoch: 141 || EpochTime: 0m21s
# 	Train Loss: 0.158 || Train Acc: 94.62%
# 	 Val Loss: 0.294 ||  Val Acc: 91.93%
# Epoch: 142 || EpochTime: 0m21s
# 	Train Loss: 0.161 || Train Acc: 94.51%
# 	 Val Loss: 0.293 ||  Val Acc: 92.09%
# Epoch: 143 || EpochTime: 0m21s
# 	Train Loss: 0.163 || Train Acc: 94.38%
# 	 Val Loss: 0.296 ||  Val Acc: 91.81%
# Epoch: 144 || EpochTime: 0m21s
# 	Train Loss: 0.157 || Train Acc: 94.61%
# 	 Val Loss: 0.290 ||  Val Acc: 92.15%
# Epoch: 145 || EpochTime: 0m21s
# 	Train Loss: 0.162 || Train Acc: 94.54%
# 	 Val Loss: 0.293 ||  Val Acc: 91.91%
# Epoch: 146 || EpochTime: 0m21s
# 	Train Loss: 0.160 || Train Acc: 94.42%
# 	 Val Loss: 0.288 ||  Val Acc: 91.85%
# Epoch: 147 || EpochTime: 0m21s
# 	Train Loss: 0.157 || Train Acc: 94.56%
# 	 Val Loss: 0.295 ||  Val Acc: 91.95%
# Epoch: 148 || EpochTime: 0m21s
# 	Train Loss: 0.157 || Train Acc: 94.55%
# 	 Val Loss: 0.292 ||  Val Acc: 92.01%
# Epoch: 149 || EpochTime: 0m21s
# 	Train Loss: 0.162 || Train Acc: 94.37%
# 	 Val Loss: 0.297 ||  Val Acc: 91.95%
# Epoch: 150 || EpochTime: 0m21s
# 	Train Loss: 0.157 || Train Acc: 94.67%
# 	 Val Loss: 0.291 ||  Val Acc: 91.97%

# %%
# visualize the loss as the network trained
def get_loss_plot(train_loss, val_loss):
    plt.plot(range(len(train_loss)),train_loss)
    plt.plot(range(len(train_loss)),val_loss)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.title('Loss')
    plt.legend(['Training Loss', 'Validation Loss'])
    plt.savefig('Model_1.png')
    plt.show()
    
    
# Prints training loss and validation loss 
get_loss_plot(Train_Loss, Val_Loss)

# %% [markdown]
# #5.  Evaluate Best Saved Model on Test Dataset

# %%
# Load saved model's parameters
model.load_state_dict(torch.load('Model_1.pt'))

# Calculate test loss and accuracy
test_loss, test_acc = evaluate(model, test_dataloader, criterion, device)


print(f'Test Loss: {test_loss:.3f} || Test Acc: {test_acc*100:.2f}%')
# Out:
# Test Loss: 0.285 || Test Acc: 91.70%
