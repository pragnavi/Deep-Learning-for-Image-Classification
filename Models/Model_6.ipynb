# %%
import torch, torchvision
import torchvision.transforms as transforms
import torch.nn as nn, torch.nn.functional as F
import torch.optim as optim, torch.utils.data as data
import torchvision.datasets as datasets
import time, copy, random, os, numpy as np
import matplotlib.pyplot as plt
from torchvision.transforms.autoaugment import AutoAugmentPolicy
from torch.optim.lr_scheduler import ReduceLROnPlateau, OneCycleLR
from torch.utils.data import random_split
from torchsummary import summary

# %%
BATCH_SIZE = 64
INPUT_SIZE = (3, 32, 32)
EPOCHS = 150
LEARNING_RATE = 1e-3

# %%
#Verify GPU
# !nvidia-smi
# Out:
# Tue Apr 11 19:29:39 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    42W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Specify device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Sets the seed for numpy and torch to make sure functions with a random component behave deterministically
# torch.backends.cudnn.deterministic = true sets the CuDNN to deterministic mode.
# This function allows us to run experiments 100% deterministically.
# https://gist.github.com/ihoromi4/b681a9088f348942b01711f251e5f964

def seed_everything(seed=1234):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything()

# %% [markdown]
# # 1.  Load and Batch the Data

# %%
def get_data_loaders(batch_size, root = '.data', valid_ratio = 0.1):
  
    #means and stds for the 3 channels of the dataset
    means = (0.4914, 0.4822, 0.4465)
    stds = (0.2023, 0.1994, 0.2010)

    #   Performs the following data augmentations on the training set:
    #       1.  Random Rotation:  
    #       2.  RandomHorizontalFlip
    #       3.  Random Crop
    #       4.  AutoAugment: AutoAugmention policies learned from the CIFAR10 dataset
    #           AutoAugment: Learning Augmentation Strategies from Data" <https://arxiv.org/pdf/1805.09501.pdf>`
    train_transforms = transforms.Compose([
                           transforms.RandomRotation(5),
                           transforms.RandomHorizontalFlip(0.5),
                           transforms.RandomCrop(32, padding = 2),
                           transforms.AutoAugment(AutoAugmentPolicy.CIFAR10),
                           transforms.ToTensor(),  # convert data to torch.FloatTensor: CxHxW
                           transforms.Normalize(mean = means, std = stds, inplace=True), #Range is in [-1,1], data = (data - mean)/std
                       ])

    test_transforms = transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize(mean = means, std = stds, inplace=True),
                       ])

    # choose the training and test datasets
    train_data = datasets.CIFAR10(root, 
                              train = True, 
                              download = True, 
                              transform = train_transforms)
    
    test_data = datasets.CIFAR10(root, 
                             train = False, 
                             download = True, 
                             transform = test_transforms)
    
    # obtain number of training/validation examples that will be used to create the respective datasets 
    n_train_examples = int((1 - valid_ratio) * len(train_data))
    n_valid_examples = int(valid_ratio* len(train_data))

    train_data, valid_data = random_split(train_data, [n_train_examples, n_valid_examples])
    
    #Creates a deep copy
    valid_data = copy.deepcopy(valid_data)  
    valid_data.dataset.transform = test_transforms

    # load training data in batches
    train_dataloader = data.DataLoader(train_data,
                                 shuffle = True,
                                 batch_size = batch_size,
                                 num_workers=2, 
                                 pin_memory=True)   #pin_memory speeds transfer of data from CPU to GPU

    # load validation data in batches
    valid_dataloader = data.DataLoader(valid_data,
                                 batch_size = batch_size,
                                 num_workers=2, 
                                 pin_memory=True)

    # load test data in batches
    test_dataloader = data.DataLoader(test_data,
                                batch_size = batch_size,
                                num_workers=2, 
                                pin_memory=True)
  
    return train_dataloader, valid_dataloader, test_dataloader

# %%
# Load and batch the data
train_dataloader, valid_dataloader, test_dataloader = get_data_loaders(BATCH_SIZE)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to .data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:04<00:00, 39121216.74it/s]
# Extracting .data/cifar-10-python.tar.gz to .data
# Files already downloaded and verified

# %% [markdown]
# # 2.  Define the Network

# %%
'''ResNet in PyTorch.
For Pre-activation ResNet, see 'preact_resnet.py'.
Reference:
[1] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun
    Deep Residual Learning for Image Recognition. arXiv:1512.03385
'''

#Residual Block
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=3,padding=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

#1. Convolutional Layer: conv1
#2. Residual Layers: layer1, layer2, layer3, layer4
#3. Fully Connected Layer: linear
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 32

        self.conv1 = nn.Conv2d(3, 32, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 128, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 256, num_blocks[3], stride=2)
        self.linear = nn.Linear(256*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

#ResNet18 has 4 residual layers, each composed of a specifed number of residual blocks
def ResNet18():
    return ResNet(BasicBlock, [5,4,3,2])

# %% [markdown]
# # 3.  Specify Model, Loss Function, Optimizer, and Scheduler

# %%
# Specify the model, loss function, and optimizer; move model to device
model = ResNet18().to(device)
criterion = nn.CrossEntropyLoss()
#optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
optimizer = torch.optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=0.9)

# Specify scheduler
#scheduler = ReduceLROnPlateau(optimizer, 'min')

# %%
# Check total number of parameters
summary(model, input_size=INPUT_SIZE)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#             Conv2d-3           [-1, 64, 32, 32]          18,432
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#             Conv2d-7           [-1, 64, 32, 32]          18,432
#        BatchNorm2d-8           [-1, 64, 32, 32]             128
#         BasicBlock-9           [-1, 64, 32, 32]               0
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#            Conv2d-12           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-13           [-1, 64, 32, 32]             128
#        BasicBlock-14           [-1, 64, 32, 32]               0
#            Conv2d-15           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-16           [-1, 64, 32, 32]             128
#            Conv2d-17           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-18           [-1, 64, 32, 32]             128
#        BasicBlock-19           [-1, 64, 32, 32]               0
#            Conv2d-20           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-21           [-1, 64, 32, 32]             128
#            Conv2d-22           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-23           [-1, 64, 32, 32]             128
#        BasicBlock-24           [-1, 64, 32, 32]               0
#            Conv2d-25           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-26           [-1, 64, 32, 32]             128
#            Conv2d-27           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-28           [-1, 64, 32, 32]             128
#        BasicBlock-29           [-1, 64, 32, 32]               0
#            Conv2d-30          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-31          [-1, 128, 16, 16]             256
#            Conv2d-32          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-33          [-1, 128, 16, 16]             256
#            Conv2d-34          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-35          [-1, 128, 16, 16]             256
#        BasicBlock-36          [-1, 128, 16, 16]               0
#            Conv2d-37          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-38          [-1, 128, 16, 16]             256
#            Conv2d-39          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-40          [-1, 128, 16, 16]             256
#        BasicBlock-41          [-1, 128, 16, 16]               0
#            Conv2d-42          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-43          [-1, 128, 16, 16]             256
#            Conv2d-44          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-45          [-1, 128, 16, 16]             256
#        BasicBlock-46          [-1, 128, 16, 16]               0
#            Conv2d-47          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-48          [-1, 128, 16, 16]             256
#            Conv2d-49          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-50          [-1, 128, 16, 16]             256
#        BasicBlock-51          [-1, 128, 16, 16]               0
#            Conv2d-52            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-53            [-1, 128, 8, 8]             256
#            Conv2d-54            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-55            [-1, 128, 8, 8]             256
#            Conv2d-56            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-57            [-1, 128, 8, 8]             256
#        BasicBlock-58            [-1, 128, 8, 8]               0
#            Conv2d-59            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-60            [-1, 128, 8, 8]             256
#            Conv2d-61            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-62            [-1, 128, 8, 8]             256
#        BasicBlock-63            [-1, 128, 8, 8]               0
#            Conv2d-64            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-65            [-1, 128, 8, 8]             256
#            Conv2d-66            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-67            [-1, 128, 8, 8]             256
#        BasicBlock-68            [-1, 128, 8, 8]               0
#            Conv2d-69            [-1, 256, 4, 4]         294,912
#       BatchNorm2d-70            [-1, 256, 4, 4]             512
#            Conv2d-71            [-1, 256, 4, 4]         589,824
#       BatchNorm2d-72            [-1, 256, 4, 4]             512
#            Conv2d-73            [-1, 256, 4, 4]         294,912
#       BatchNorm2d-74            [-1, 256, 4, 4]             512
#        BasicBlock-75            [-1, 256, 4, 4]               0
#            Conv2d-76            [-1, 256, 4, 4]         589,824
#       BatchNorm2d-77            [-1, 256, 4, 4]             512
#            Conv2d-78            [-1, 256, 4, 4]         589,824
#       BatchNorm2d-79            [-1, 256, 4, 4]             512
#        BasicBlock-80            [-1, 256, 4, 4]               0
#            Linear-81                   [-1, 10]           2,570
# ================================================================
# Total params: 4,951,338
# Trainable params: 4,951,338
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 20.94
# Params size (MB): 18.89
# Estimated Total Size (MB): 39.84
# ----------------------------------------------------------------

# %% [markdown]
# #4. Training and Validation

# %%
# accuracy is the fraction of predictions the model got correct
def calculate_accuracy(y_pred, y):
    top_pred = y_pred.argmax(1, keepdim = True)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    acc = correct.float() / y.shape[0]
    return acc

# time interval for each epoch
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
def train(model, iterator, optimizer, criterion, device):
    
    # Tracks training loss and accuracy as model trains
    epoch_loss = 0
    epoch_acc = 0
    #lrs = []

    # Prep model for training
    model.train()

    for (x, y) in iterator:
        # Move inputs and labels to device
        x = x.to(device)
        y = y.to(device)
        
        # Clear the gradients of all optimized variables
        optimizer.zero_grad()

        # Forward pass: compute predicted outputs by passing inputs to the model        
        y_pred = model(x)
        
        # Calculate the loss
        loss = criterion(y_pred, y)
        
        # Calculate the accuracy
        acc = calculate_accuracy(y_pred, y)
        
        # Backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()

        #OneCycleLr Scheduler
        #scheduler.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def evaluate(model, iterator, criterion, device):
    # Keeps track of validation loss and  accuracy
    epoch_loss = 0
    epoch_acc = 0
    
    # Prep model for evaluation
    model.eval()
    
    with torch.no_grad():
        
        for (x, y) in iterator:

            x = x.to(device)
            y = y.to(device)

            # Forward Pass
            y_pred = model(x)
            # Calculate the validation loss
            loss = criterion(y_pred, y)
            #Calculate the validation accuracy
            acc = calculate_accuracy(y_pred, y)

            #Record validation loss
            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
# Train and Validate the model:

# Tracks average training loss and accuracy per epoch
#  and tracks average validation loss and accuracy per epoch
Train_Loss = []
Train_Acc = []
Val_Loss = []
Val_Acc = []


# Tracks best validation loss
best_valid_loss = float('inf')
for epoch in range(EPOCHS):
    # Epoch start time
    start_time = time.monotonic()


    train_loss, train_acc = train(model, train_dataloader, optimizer, criterion, device)
    valid_loss, valid_acc = evaluate(model, valid_dataloader, criterion, device)
  

    # OnReducePlateau is a scheduler monitoring validation loss
    #scheduler.step(valid_loss)

    # Saves model with best validation loss in a state dictionary
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(),'Model.pt')
    # Epoch end time
    end_time = time.monotonic()

    # Prints training/validation statistics as well as epoch time
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    print(f'Epoch: {epoch+1:02} || EpochTime: {epoch_mins}m{epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} || Train Acc: {train_acc*100:.2f}%')
    print(f'\t Val Loss: {valid_loss:.3f} ||  Val Acc: {valid_acc*100:.2f}%')

    Train_Loss.append(train_loss)
    Train_Acc.append(train_acc)
    Val_Loss.append(valid_loss)
    Val_Acc.append(valid_acc)
# Out:
# Epoch: 01 || EpochTime: 0m21s
# 	Train Loss: 1.839 || Train Acc: 32.12%
# 	 Val Loss: 1.368 ||  Val Acc: 50.47%
# Epoch: 02 || EpochTime: 0m21s
# 	Train Loss: 1.437 || Train Acc: 48.08%
# 	 Val Loss: 1.066 ||  Val Acc: 61.51%
# Epoch: 03 || EpochTime: 0m21s
# 	Train Loss: 1.206 || Train Acc: 57.01%
# 	 Val Loss: 0.994 ||  Val Acc: 65.80%
# Epoch: 04 || EpochTime: 0m20s
# 	Train Loss: 1.057 || Train Acc: 62.69%
# 	 Val Loss: 0.889 ||  Val Acc: 69.88%
# Epoch: 05 || EpochTime: 0m21s
# 	Train Loss: 0.945 || Train Acc: 66.56%
# 	 Val Loss: 0.725 ||  Val Acc: 74.11%
# Epoch: 06 || EpochTime: 0m21s
# 	Train Loss: 0.863 || Train Acc: 69.66%
# 	 Val Loss: 0.638 ||  Val Acc: 77.73%
# Epoch: 07 || EpochTime: 0m21s
# 	Train Loss: 0.801 || Train Acc: 72.08%
# 	 Val Loss: 0.646 ||  Val Acc: 77.75%
# Epoch: 08 || EpochTime: 0m21s
# 	Train Loss: 0.756 || Train Acc: 73.78%
# 	 Val Loss: 0.590 ||  Val Acc: 79.94%
# Epoch: 09 || EpochTime: 0m21s
# 	Train Loss: 0.712 || Train Acc: 74.98%
# 	 Val Loss: 0.512 ||  Val Acc: 82.54%
# Epoch: 10 || EpochTime: 0m21s
# 	Train Loss: 0.673 || Train Acc: 76.53%
# 	 Val Loss: 0.465 ||  Val Acc: 83.62%
# Epoch: 11 || EpochTime: 0m21s
# 	Train Loss: 0.646 || Train Acc: 77.55%
# 	 Val Loss: 0.520 ||  Val Acc: 81.76%
# Epoch: 12 || EpochTime: 0m21s
# 	Train Loss: 0.614 || Train Acc: 78.79%
# 	 Val Loss: 0.471 ||  Val Acc: 83.84%
# Epoch: 13 || EpochTime: 0m21s
# 	Train Loss: 0.597 || Train Acc: 79.17%
# 	 Val Loss: 0.449 ||  Val Acc: 84.75%
# Epoch: 14 || EpochTime: 0m20s
# 	Train Loss: 0.569 || Train Acc: 80.09%
# 	 Val Loss: 0.457 ||  Val Acc: 83.92%
# Epoch: 15 || EpochTime: 0m22s
# 	Train Loss: 0.552 || Train Acc: 80.71%
# 	 Val Loss: 0.441 ||  Val Acc: 85.07%
# Epoch: 16 || EpochTime: 0m21s
# 	Train Loss: 0.531 || Train Acc: 81.58%
# 	 Val Loss: 0.420 ||  Val Acc: 85.58%
# Epoch: 17 || EpochTime: 0m21s
# 	Train Loss: 0.518 || Train Acc: 81.74%
# 	 Val Loss: 0.403 ||  Val Acc: 86.27%
# Epoch: 18 || EpochTime: 0m21s
# 	Train Loss: 0.498 || Train Acc: 82.65%
# 	 Val Loss: 0.411 ||  Val Acc: 86.63%
# Epoch: 19 || EpochTime: 0m21s
# 	Train Loss: 0.485 || Train Acc: 83.26%
# 	 Val Loss: 0.402 ||  Val Acc: 86.45%
# Epoch: 20 || EpochTime: 0m21s
# 	Train Loss: 0.476 || Train Acc: 83.46%
# 	 Val Loss: 0.373 ||  Val Acc: 87.30%
# Epoch: 21 || EpochTime: 0m22s
# 	Train Loss: 0.463 || Train Acc: 83.83%
# 	 Val Loss: 0.379 ||  Val Acc: 87.52%
# Epoch: 22 || EpochTime: 0m21s
# 	Train Loss: 0.446 || Train Acc: 84.57%
# 	 Val Loss: 0.367 ||  Val Acc: 87.03%
# Epoch: 23 || EpochTime: 0m21s
# 	Train Loss: 0.440 || Train Acc: 84.67%
# 	 Val Loss: 0.350 ||  Val Acc: 87.86%
# Epoch: 24 || EpochTime: 0m20s
# 	Train Loss: 0.428 || Train Acc: 84.99%
# 	 Val Loss: 0.356 ||  Val Acc: 88.23%
# Epoch: 25 || EpochTime: 0m21s
# 	Train Loss: 0.414 || Train Acc: 85.51%
# 	 Val Loss: 0.350 ||  Val Acc: 88.45%
# Epoch: 26 || EpochTime: 0m21s
# 	Train Loss: 0.411 || Train Acc: 85.74%
# 	 Val Loss: 0.334 ||  Val Acc: 88.55%
# Epoch: 27 || EpochTime: 0m21s
# 	Train Loss: 0.398 || Train Acc: 86.22%
# 	 Val Loss: 0.341 ||  Val Acc: 88.57%
# Epoch: 28 || EpochTime: 0m21s
# 	Train Loss: 0.394 || Train Acc: 86.22%
# 	 Val Loss: 0.331 ||  Val Acc: 88.69%
# Epoch: 29 || EpochTime: 0m21s
# 	Train Loss: 0.389 || Train Acc: 86.30%
# 	 Val Loss: 0.334 ||  Val Acc: 88.96%
# Epoch: 30 || EpochTime: 0m21s
# 	Train Loss: 0.381 || Train Acc: 86.69%
# 	 Val Loss: 0.336 ||  Val Acc: 88.23%
# Epoch: 31 || EpochTime: 0m21s
# 	Train Loss: 0.369 || Train Acc: 87.02%
# 	 Val Loss: 0.309 ||  Val Acc: 89.79%
# Epoch: 32 || EpochTime: 0m21s
# 	Train Loss: 0.358 || Train Acc: 87.37%
# 	 Val Loss: 0.295 ||  Val Acc: 90.17%
# Epoch: 33 || EpochTime: 0m21s
# 	Train Loss: 0.354 || Train Acc: 87.50%
# 	 Val Loss: 0.316 ||  Val Acc: 90.09%
# Epoch: 34 || EpochTime: 0m21s
# 	Train Loss: 0.354 || Train Acc: 87.71%
# 	 Val Loss: 0.318 ||  Val Acc: 89.52%
# Epoch: 35 || EpochTime: 0m21s
# 	Train Loss: 0.341 || Train Acc: 88.12%
# 	 Val Loss: 0.324 ||  Val Acc: 89.52%
# Epoch: 36 || EpochTime: 0m21s
# 	Train Loss: 0.338 || Train Acc: 88.24%
# 	 Val Loss: 0.320 ||  Val Acc: 90.15%
# Epoch: 37 || EpochTime: 0m21s
# 	Train Loss: 0.329 || Train Acc: 88.61%
# 	 Val Loss: 0.307 ||  Val Acc: 89.99%
# Epoch: 38 || EpochTime: 0m21s
# 	Train Loss: 0.329 || Train Acc: 88.46%
# 	 Val Loss: 0.307 ||  Val Acc: 89.87%
# Epoch: 39 || EpochTime: 0m21s
# 	Train Loss: 0.319 || Train Acc: 88.82%
# 	 Val Loss: 0.303 ||  Val Acc: 90.33%
# Epoch: 40 || EpochTime: 0m21s
# 	Train Loss: 0.311 || Train Acc: 89.16%
# 	 Val Loss: 0.301 ||  Val Acc: 90.25%
# Epoch: 41 || EpochTime: 0m21s
# 	Train Loss: 0.311 || Train Acc: 89.22%
# 	 Val Loss: 0.294 ||  Val Acc: 90.35%
# Epoch: 42 || EpochTime: 0m21s
# 	Train Loss: 0.311 || Train Acc: 89.11%
# 	 Val Loss: 0.285 ||  Val Acc: 90.74%
# Epoch: 43 || EpochTime: 0m22s
# 	Train Loss: 0.298 || Train Acc: 89.60%
# 	 Val Loss: 0.324 ||  Val Acc: 89.44%
# Epoch: 44 || EpochTime: 0m21s
# 	Train Loss: 0.291 || Train Acc: 89.84%
# 	 Val Loss: 0.292 ||  Val Acc: 90.59%
# Epoch: 45 || EpochTime: 0m22s
# 	Train Loss: 0.289 || Train Acc: 89.98%
# 	 Val Loss: 0.294 ||  Val Acc: 90.96%
# Epoch: 46 || EpochTime: 0m21s
# 	Train Loss: 0.287 || Train Acc: 90.04%
# 	 Val Loss: 0.313 ||  Val Acc: 89.79%
# Epoch: 47 || EpochTime: 0m21s
# 	Train Loss: 0.282 || Train Acc: 90.11%
# 	 Val Loss: 0.299 ||  Val Acc: 90.19%
# Epoch: 48 || EpochTime: 0m21s
# 	Train Loss: 0.282 || Train Acc: 90.16%
# 	 Val Loss: 0.280 ||  Val Acc: 91.38%
# Epoch: 49 || EpochTime: 0m22s
# 	Train Loss: 0.279 || Train Acc: 90.16%
# 	 Val Loss: 0.305 ||  Val Acc: 90.47%
# Epoch: 50 || EpochTime: 0m21s
# 	Train Loss: 0.273 || Train Acc: 90.54%
# 	 Val Loss: 0.278 ||  Val Acc: 91.06%
# Epoch: 51 || EpochTime: 0m21s
# 	Train Loss: 0.268 || Train Acc: 90.71%
# 	 Val Loss: 0.325 ||  Val Acc: 89.75%
# Epoch: 52 || EpochTime: 0m21s
# 	Train Loss: 0.260 || Train Acc: 91.05%
# 	 Val Loss: 0.284 ||  Val Acc: 91.08%
# Epoch: 53 || EpochTime: 0m21s
# 	Train Loss: 0.259 || Train Acc: 90.97%
# 	 Val Loss: 0.291 ||  Val Acc: 90.96%
# Epoch: 54 || EpochTime: 0m21s
# 	Train Loss: 0.258 || Train Acc: 90.86%
# 	 Val Loss: 0.293 ||  Val Acc: 90.78%
# Epoch: 55 || EpochTime: 0m21s
# 	Train Loss: 0.261 || Train Acc: 90.88%
# 	 Val Loss: 0.300 ||  Val Acc: 90.78%
# Epoch: 56 || EpochTime: 0m21s
# 	Train Loss: 0.252 || Train Acc: 91.27%
# 	 Val Loss: 0.294 ||  Val Acc: 91.18%
# Epoch: 57 || EpochTime: 0m21s
# 	Train Loss: 0.250 || Train Acc: 91.18%
# 	 Val Loss: 0.317 ||  Val Acc: 90.21%
# Epoch: 58 || EpochTime: 0m21s
# 	Train Loss: 0.242 || Train Acc: 91.51%
# 	 Val Loss: 0.311 ||  Val Acc: 90.84%
# Epoch: 59 || EpochTime: 0m21s
# 	Train Loss: 0.242 || Train Acc: 91.60%
# 	 Val Loss: 0.269 ||  Val Acc: 91.67%
# Epoch: 60 || EpochTime: 0m21s
# 	Train Loss: 0.238 || Train Acc: 91.64%
# 	 Val Loss: 0.290 ||  Val Acc: 91.75%
# Epoch: 61 || EpochTime: 0m21s
# 	Train Loss: 0.234 || Train Acc: 91.90%
# 	 Val Loss: 0.262 ||  Val Acc: 92.17%
# Epoch: 62 || EpochTime: 0m21s
# 	Train Loss: 0.234 || Train Acc: 91.83%
# 	 Val Loss: 0.282 ||  Val Acc: 91.52%
# Epoch: 63 || EpochTime: 0m21s
# 	Train Loss: 0.239 || Train Acc: 91.74%
# 	 Val Loss: 0.303 ||  Val Acc: 90.84%
# Epoch: 64 || EpochTime: 0m21s
# 	Train Loss: 0.224 || Train Acc: 92.10%
# 	 Val Loss: 0.308 ||  Val Acc: 90.76%
# Epoch: 65 || EpochTime: 0m21s
# 	Train Loss: 0.229 || Train Acc: 91.94%
# 	 Val Loss: 0.268 ||  Val Acc: 91.75%
# Epoch: 66 || EpochTime: 0m21s
# 	Train Loss: 0.225 || Train Acc: 92.06%
# 	 Val Loss: 0.271 ||  Val Acc: 91.55%
# Epoch: 67 || EpochTime: 0m21s
# 	Train Loss: 0.221 || Train Acc: 92.35%
# 	 Val Loss: 0.271 ||  Val Acc: 91.85%
# Epoch: 68 || EpochTime: 0m21s
# 	Train Loss: 0.214 || Train Acc: 92.46%
# 	 Val Loss: 0.303 ||  Val Acc: 90.96%
# Epoch: 69 || EpochTime: 0m21s
# 	Train Loss: 0.222 || Train Acc: 92.25%
# 	 Val Loss: 0.283 ||  Val Acc: 91.46%
# Epoch: 70 || EpochTime: 0m21s
# 	Train Loss: 0.212 || Train Acc: 92.63%
# 	 Val Loss: 0.294 ||  Val Acc: 91.34%
# Epoch: 71 || EpochTime: 0m21s
# 	Train Loss: 0.212 || Train Acc: 92.84%
# 	 Val Loss: 0.269 ||  Val Acc: 91.93%
# Epoch: 72 || EpochTime: 0m21s
# 	Train Loss: 0.211 || Train Acc: 92.59%
# 	 Val Loss: 0.278 ||  Val Acc: 91.83%
# Epoch: 73 || EpochTime: 0m21s
# 	Train Loss: 0.212 || Train Acc: 92.71%
# 	 Val Loss: 0.290 ||  Val Acc: 91.52%
# Epoch: 74 || EpochTime: 0m21s
# 	Train Loss: 0.205 || Train Acc: 92.89%
# 	 Val Loss: 0.248 ||  Val Acc: 92.39%
# Epoch: 75 || EpochTime: 0m21s
# 	Train Loss: 0.202 || Train Acc: 92.87%
# 	 Val Loss: 0.262 ||  Val Acc: 92.44%
# Epoch: 76 || EpochTime: 0m21s
# 	Train Loss: 0.204 || Train Acc: 92.90%
# 	 Val Loss: 0.260 ||  Val Acc: 92.27%
# Epoch: 77 || EpochTime: 0m21s
# 	Train Loss: 0.203 || Train Acc: 93.03%
# 	 Val Loss: 0.261 ||  Val Acc: 92.17%
# Epoch: 78 || EpochTime: 0m21s
# 	Train Loss: 0.198 || Train Acc: 93.09%
# 	 Val Loss: 0.271 ||  Val Acc: 92.41%
# Epoch: 79 || EpochTime: 0m21s
# 	Train Loss: 0.193 || Train Acc: 93.41%
# 	 Val Loss: 0.280 ||  Val Acc: 92.27%
# Epoch: 80 || EpochTime: 0m22s
# 	Train Loss: 0.198 || Train Acc: 93.14%
# 	 Val Loss: 0.281 ||  Val Acc: 91.99%
# Epoch: 81 || EpochTime: 0m21s
# 	Train Loss: 0.195 || Train Acc: 93.39%
# 	 Val Loss: 0.311 ||  Val Acc: 90.68%
# Epoch: 82 || EpochTime: 0m21s
# 	Train Loss: 0.191 || Train Acc: 93.39%
# 	 Val Loss: 0.275 ||  Val Acc: 91.95%
# Epoch: 83 || EpochTime: 0m21s
# 	Train Loss: 0.196 || Train Acc: 93.19%
# 	 Val Loss: 0.300 ||  Val Acc: 91.65%
# Epoch: 84 || EpochTime: 0m21s
# 	Train Loss: 0.193 || Train Acc: 93.39%
# 	 Val Loss: 0.273 ||  Val Acc: 91.91%
# Epoch: 85 || EpochTime: 0m21s
# 	Train Loss: 0.188 || Train Acc: 93.39%
# 	 Val Loss: 0.269 ||  Val Acc: 92.27%
# Epoch: 86 || EpochTime: 0m21s
# 	Train Loss: 0.187 || Train Acc: 93.54%
# 	 Val Loss: 0.288 ||  Val Acc: 91.93%
# Epoch: 87 || EpochTime: 0m21s
# 	Train Loss: 0.183 || Train Acc: 93.58%
# 	 Val Loss: 0.258 ||  Val Acc: 92.37%
# Epoch: 88 || EpochTime: 0m21s
# 	Train Loss: 0.184 || Train Acc: 93.69%
# 	 Val Loss: 0.257 ||  Val Acc: 92.60%
# Epoch: 89 || EpochTime: 0m21s
# 	Train Loss: 0.186 || Train Acc: 93.59%
# 	 Val Loss: 0.266 ||  Val Acc: 92.15%
# Epoch: 90 || EpochTime: 0m21s
# 	Train Loss: 0.181 || Train Acc: 93.82%
# 	 Val Loss: 0.275 ||  Val Acc: 92.39%
# Epoch: 91 || EpochTime: 0m21s
# 	Train Loss: 0.180 || Train Acc: 93.69%
# 	 Val Loss: 0.303 ||  Val Acc: 91.59%
# Epoch: 92 || EpochTime: 0m21s
# 	Train Loss: 0.177 || Train Acc: 93.78%
# 	 Val Loss: 0.279 ||  Val Acc: 92.21%
# Epoch: 93 || EpochTime: 0m21s
# 	Train Loss: 0.172 || Train Acc: 93.99%
# 	 Val Loss: 0.277 ||  Val Acc: 92.09%
# Epoch: 94 || EpochTime: 0m21s
# 	Train Loss: 0.183 || Train Acc: 93.64%
# 	 Val Loss: 0.281 ||  Val Acc: 91.87%
# Epoch: 95 || EpochTime: 0m21s
# 	Train Loss: 0.177 || Train Acc: 94.00%
# 	 Val Loss: 0.264 ||  Val Acc: 92.74%
# Epoch: 96 || EpochTime: 0m21s
# 	Train Loss: 0.176 || Train Acc: 93.91%
# 	 Val Loss: 0.248 ||  Val Acc: 92.62%
# Epoch: 97 || EpochTime: 0m21s
# 	Train Loss: 0.177 || Train Acc: 93.93%
# 	 Val Loss: 0.257 ||  Val Acc: 92.78%
# Epoch: 98 || EpochTime: 0m21s
# 	Train Loss: 0.170 || Train Acc: 94.02%
# 	 Val Loss: 0.277 ||  Val Acc: 92.48%
# Epoch: 99 || EpochTime: 0m22s
# 	Train Loss: 0.171 || Train Acc: 94.05%
# 	 Val Loss: 0.281 ||  Val Acc: 92.37%
# Epoch: 100 || EpochTime: 0m21s
# 	Train Loss: 0.172 || Train Acc: 94.06%
# 	 Val Loss: 0.262 ||  Val Acc: 92.54%
# Epoch: 101 || EpochTime: 0m22s
# 	Train Loss: 0.169 || Train Acc: 94.09%
# 	 Val Loss: 0.275 ||  Val Acc: 92.41%
# Epoch: 102 || EpochTime: 0m21s
# 	Train Loss: 0.172 || Train Acc: 94.12%
# 	 Val Loss: 0.270 ||  Val Acc: 92.60%
# Epoch: 103 || EpochTime: 0m21s
# 	Train Loss: 0.169 || Train Acc: 94.22%
# 	 Val Loss: 0.271 ||  Val Acc: 92.72%
# Epoch: 104 || EpochTime: 0m21s
# 	Train Loss: 0.166 || Train Acc: 94.21%
# 	 Val Loss: 0.261 ||  Val Acc: 92.66%
# Epoch: 105 || EpochTime: 0m21s
# 	Train Loss: 0.161 || Train Acc: 94.41%
# 	 Val Loss: 0.258 ||  Val Acc: 92.46%
# Epoch: 106 || EpochTime: 0m21s
# 	Train Loss: 0.159 || Train Acc: 94.39%
# 	 Val Loss: 0.273 ||  Val Acc: 92.19%
# Epoch: 107 || EpochTime: 0m22s
# 	Train Loss: 0.163 || Train Acc: 94.36%
# 	 Val Loss: 0.274 ||  Val Acc: 92.80%
# Epoch: 108 || EpochTime: 0m21s
# 	Train Loss: 0.160 || Train Acc: 94.42%
# 	 Val Loss: 0.267 ||  Val Acc: 92.66%
# Epoch: 109 || EpochTime: 0m21s
# 	Train Loss: 0.160 || Train Acc: 94.43%
# 	 Val Loss: 0.256 ||  Val Acc: 93.04%
# Epoch: 110 || EpochTime: 0m21s
# 	Train Loss: 0.157 || Train Acc: 94.52%
# 	 Val Loss: 0.258 ||  Val Acc: 92.90%
# Epoch: 111 || EpochTime: 0m21s
# 	Train Loss: 0.161 || Train Acc: 94.35%
# 	 Val Loss: 0.270 ||  Val Acc: 92.82%
# Epoch: 112 || EpochTime: 0m21s
# 	Train Loss: 0.151 || Train Acc: 94.74%
# 	 Val Loss: 0.278 ||  Val Acc: 92.48%
# Epoch: 113 || EpochTime: 0m21s
# 	Train Loss: 0.156 || Train Acc: 94.66%
# 	 Val Loss: 0.254 ||  Val Acc: 92.94%
# Epoch: 114 || EpochTime: 0m21s
# 	Train Loss: 0.150 || Train Acc: 94.85%
# 	 Val Loss: 0.257 ||  Val Acc: 93.00%
# Epoch: 115 || EpochTime: 0m21s
# 	Train Loss: 0.156 || Train Acc: 94.59%
# 	 Val Loss: 0.263 ||  Val Acc: 92.86%
# Epoch: 116 || EpochTime: 0m21s
# 	Train Loss: 0.151 || Train Acc: 94.73%
# 	 Val Loss: 0.274 ||  Val Acc: 92.46%
# Epoch: 117 || EpochTime: 0m21s
# 	Train Loss: 0.154 || Train Acc: 94.67%
# 	 Val Loss: 0.255 ||  Val Acc: 93.35%
# Epoch: 118 || EpochTime: 0m21s
# 	Train Loss: 0.153 || Train Acc: 94.65%
# 	 Val Loss: 0.264 ||  Val Acc: 93.04%
# Epoch: 119 || EpochTime: 0m21s
# 	Train Loss: 0.154 || Train Acc: 94.74%
# 	 Val Loss: 0.252 ||  Val Acc: 92.82%
# Epoch: 120 || EpochTime: 0m21s
# 	Train Loss: 0.152 || Train Acc: 94.80%
# 	 Val Loss: 0.243 ||  Val Acc: 93.39%
# Epoch: 121 || EpochTime: 0m21s
# 	Train Loss: 0.145 || Train Acc: 95.03%
# 	 Val Loss: 0.275 ||  Val Acc: 92.62%
# Epoch: 122 || EpochTime: 0m21s
# 	Train Loss: 0.148 || Train Acc: 94.84%
# 	 Val Loss: 0.248 ||  Val Acc: 93.30%
# Epoch: 123 || EpochTime: 0m21s
# 	Train Loss: 0.147 || Train Acc: 94.94%
# 	 Val Loss: 0.267 ||  Val Acc: 92.66%
# Epoch: 124 || EpochTime: 0m21s
# 	Train Loss: 0.149 || Train Acc: 94.79%
# 	 Val Loss: 0.256 ||  Val Acc: 93.31%
# Epoch: 125 || EpochTime: 0m21s
# 	Train Loss: 0.145 || Train Acc: 95.03%
# 	 Val Loss: 0.275 ||  Val Acc: 92.54%
# Epoch: 126 || EpochTime: 0m21s
# 	Train Loss: 0.151 || Train Acc: 94.79%
# 	 Val Loss: 0.262 ||  Val Acc: 92.82%
# Epoch: 127 || EpochTime: 0m22s
# 	Train Loss: 0.145 || Train Acc: 95.06%
# 	 Val Loss: 0.276 ||  Val Acc: 92.82%
# Epoch: 128 || EpochTime: 0m21s
# 	Train Loss: 0.145 || Train Acc: 95.08%
# 	 Val Loss: 0.265 ||  Val Acc: 92.82%
# Epoch: 129 || EpochTime: 0m21s
# 	Train Loss: 0.147 || Train Acc: 95.07%
# 	 Val Loss: 0.291 ||  Val Acc: 92.56%
# Epoch: 130 || EpochTime: 0m21s
# 	Train Loss: 0.145 || Train Acc: 95.09%
# 	 Val Loss: 0.274 ||  Val Acc: 92.31%
# Epoch: 131 || EpochTime: 0m21s
# 	Train Loss: 0.142 || Train Acc: 95.11%
# 	 Val Loss: 0.284 ||  Val Acc: 92.98%
# Epoch: 132 || EpochTime: 0m21s
# 	Train Loss: 0.146 || Train Acc: 94.97%
# 	 Val Loss: 0.254 ||  Val Acc: 93.33%
# Epoch: 133 || EpochTime: 0m22s
# 	Train Loss: 0.144 || Train Acc: 95.00%
# 	 Val Loss: 0.256 ||  Val Acc: 93.22%
# Epoch: 134 || EpochTime: 0m21s
# 	Train Loss: 0.149 || Train Acc: 94.95%
# 	 Val Loss: 0.259 ||  Val Acc: 93.10%
# Epoch: 135 || EpochTime: 0m21s
# 	Train Loss: 0.139 || Train Acc: 95.19%
# 	 Val Loss: 0.256 ||  Val Acc: 93.14%
# Epoch: 136 || EpochTime: 0m21s
# 	Train Loss: 0.140 || Train Acc: 95.21%
# 	 Val Loss: 0.269 ||  Val Acc: 92.72%
# Epoch: 137 || EpochTime: 0m21s
# 	Train Loss: 0.137 || Train Acc: 95.23%
# 	 Val Loss: 0.253 ||  Val Acc: 93.24%
# Epoch: 138 || EpochTime: 0m21s
# 	Train Loss: 0.133 || Train Acc: 95.44%
# 	 Val Loss: 0.257 ||  Val Acc: 93.37%
# Epoch: 139 || EpochTime: 0m21s
# 	Train Loss: 0.138 || Train Acc: 95.24%
# 	 Val Loss: 0.258 ||  Val Acc: 93.43%
# Epoch: 140 || EpochTime: 0m21s
# 	Train Loss: 0.139 || Train Acc: 95.28%
# 	 Val Loss: 0.270 ||  Val Acc: 93.26%
# Epoch: 141 || EpochTime: 0m21s
# 	Train Loss: 0.140 || Train Acc: 95.16%
# 	 Val Loss: 0.256 ||  Val Acc: 93.20%
# Epoch: 142 || EpochTime: 0m21s
# 	Train Loss: 0.135 || Train Acc: 95.43%
# 	 Val Loss: 0.252 ||  Val Acc: 93.22%
# Epoch: 143 || EpochTime: 0m21s
# 	Train Loss: 0.140 || Train Acc: 95.21%
# 	 Val Loss: 0.257 ||  Val Acc: 93.26%
# Epoch: 144 || EpochTime: 0m21s
# 	Train Loss: 0.138 || Train Acc: 95.20%
# 	 Val Loss: 0.250 ||  Val Acc: 93.35%
# Epoch: 145 || EpochTime: 0m21s
# 	Train Loss: 0.133 || Train Acc: 95.36%
# 	 Val Loss: 0.252 ||  Val Acc: 93.37%
# Epoch: 146 || EpochTime: 0m21s
# 	Train Loss: 0.140 || Train Acc: 95.26%
# 	 Val Loss: 0.270 ||  Val Acc: 93.20%
# Epoch: 147 || EpochTime: 0m21s
# 	Train Loss: 0.140 || Train Acc: 95.22%
# 	 Val Loss: 0.252 ||  Val Acc: 93.26%
# Epoch: 148 || EpochTime: 0m21s
# 	Train Loss: 0.135 || Train Acc: 95.40%
# 	 Val Loss: 0.260 ||  Val Acc: 92.80%
# Epoch: 149 || EpochTime: 0m21s
# 	Train Loss: 0.130 || Train Acc: 95.56%
# 	 Val Loss: 0.265 ||  Val Acc: 93.37%
# Epoch: 150 || EpochTime: 0m21s
# 	Train Loss: 0.132 || Train Acc: 95.48%
# 	 Val Loss: 0.252 ||  Val Acc: 93.79%

# %%
# visualize the loss as the network trained
def get_loss_plot(train_loss, val_loss):
    plt.plot(range(len(train_loss)),train_loss)
    plt.plot(range(len(train_loss)),val_loss)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.title('Loss')
    plt.legend(['Training Loss', 'Validation Loss'])
    plt.savefig('Model.png')
    plt.show()
    
    
# Prints training loss and validation loss 
get_loss_plot(Train_Loss, Val_Loss)

# %% [markdown]
# #5.  Evaluate Best Saved Model on Test Dataset

# %%
# Load saved model's parameters
model.load_state_dict(torch.load('Model.pt'))

# Calculate test loss and accuracy
test_loss, test_acc = evaluate(model, test_dataloader, criterion, device)


print(f'Test Loss: {test_loss:.3f} || Test Acc: {test_acc*100:.2f}%')
# Out:
# Test Loss: 0.248 || Test Acc: 92.92%
