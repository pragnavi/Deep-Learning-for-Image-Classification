# %%
import torch, torchvision
import torchvision.transforms as transforms
import torch.nn as nn, torch.nn.functional as F
import torch.optim as optim, torch.utils.data as data
import torchvision.datasets as datasets
import time, copy, random, os, numpy as np
import matplotlib.pyplot as plt
from torchvision.transforms.autoaugment import AutoAugmentPolicy
from torch.optim.lr_scheduler import ReduceLROnPlateau, OneCycleLR
from torch.utils.data import random_split
from torchsummary import summary

# %%
BATCH_SIZE = 64
INPUT_SIZE = (3, 32, 32)
EPOCHS = 150
LEARNING_RATE = 1e-3

# %%
#Verify GPU
# !nvidia-smi
# Out:
# Mon Apr 10 18:28:12 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0    44W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Specify device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Sets the seed for numpy and torch to make sure functions with a random component behave deterministically
# torch.backends.cudnn.deterministic = true sets the CuDNN to deterministic mode.
# This function allows us to run experiments 100% deterministically.
# https://gist.github.com/ihoromi4/b681a9088f348942b01711f251e5f964

def seed_everything(seed=1234):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything()

# %% [markdown]
# # 1.  Load and Batch the Data

# %%
def get_data_loaders(batch_size, root = '.data', valid_ratio = 0.1):
  
    #means and stds for the 3 channels of the dataset
    means = (0.4914, 0.4822, 0.4465)
    stds = (0.2023, 0.1994, 0.2010)

    #   Performs the following data augmentations on the training set:
    #       1.  Random Rotation:  
    #       2.  RandomHorizontalFlip
    #       3.  Random Crop
    #       4.  AutoAugment: AutoAugmention policies learned from the CIFAR10 dataset
    #           AutoAugment: Learning Augmentation Strategies from Data" <https://arxiv.org/pdf/1805.09501.pdf>`
    train_transforms = transforms.Compose([
                           transforms.RandomRotation(5),
                           transforms.RandomHorizontalFlip(0.5),
                           transforms.RandomCrop(32, padding = 2),
                           transforms.AutoAugment(AutoAugmentPolicy.CIFAR10),
                           transforms.ToTensor(),  # convert data to torch.FloatTensor: CxHxW
                           transforms.Normalize(mean = means, std = stds, inplace=True), #Range is in [-1,1], data = (data - mean)/std
                       ])

    test_transforms = transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize(mean = means, std = stds, inplace=True),
                       ])

    # choose the training and test datasets
    train_data = datasets.CIFAR10(root, 
                              train = True, 
                              download = True, 
                              transform = train_transforms)
    
    test_data = datasets.CIFAR10(root, 
                             train = False, 
                             download = True, 
                             transform = test_transforms)
    
    # obtain number of training/validation examples that will be used to create the respective datasets 
    n_train_examples = int((1 - valid_ratio) * len(train_data))
    n_valid_examples = int(valid_ratio* len(train_data))

    train_data, valid_data = random_split(train_data, [n_train_examples, n_valid_examples])
    
    #Creates a deep copy
    valid_data = copy.deepcopy(valid_data)  
    valid_data.dataset.transform = test_transforms

    # load training data in batches
    train_dataloader = data.DataLoader(train_data,
                                 shuffle = True,
                                 batch_size = batch_size,
                                 num_workers=2, 
                                 pin_memory=True)   #pin_memory speeds transfer of data from CPU to GPU

    # load validation data in batches
    valid_dataloader = data.DataLoader(valid_data,
                                 batch_size = batch_size,
                                 num_workers=2, 
                                 pin_memory=True)

    # load test data in batches
    test_dataloader = data.DataLoader(test_data,
                                batch_size = batch_size,
                                num_workers=2, 
                                pin_memory=True)
  
    return train_dataloader, valid_dataloader, test_dataloader

# %%
# Load and batch the data
train_dataloader, valid_dataloader, test_dataloader = get_data_loaders(BATCH_SIZE)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to .data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:13<00:00, 12866706.77it/s]
# Extracting .data/cifar-10-python.tar.gz to .data
# Files already downloaded and verified

# %% [markdown]
# # 2.  Define the Network

# %%
'''ResNet in PyTorch.
For Pre-activation ResNet, see 'preact_resnet.py'.
Reference:
[1] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun
    Deep Residual Learning for Image Recognition. arXiv:1512.03385
'''

#Residual Block
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=3,padding=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

#1. Convolutional Layer: conv1
#2. Residual Layers: layer1, layer2, layer3, layer4
#3. Fully Connected Layer: linear
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 32

        self.conv1 = nn.Conv2d(3, 32, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        self.layer1 = self._make_layer(block, 32, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 128, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 256, num_blocks[3], stride=2)
        self.linear = nn.Linear(256*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

#ResNet18 has 4 residual layers, each composed of a specifed number of residual blocks
def ResNet18():
    return ResNet(BasicBlock, [10,4,4,2])

# %% [markdown]
# # 3.  Specify Model, Loss Function, Optimizer, and Scheduler

# %%
# Specify the model, loss function, and optimizer; move model to device
model = ResNet18().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# Specify scheduler
scheduler = ReduceLROnPlateau(optimizer, 'min')

# %%
# Check total number of parameters
summary(model, input_size=INPUT_SIZE)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#             Conv2d-3           [-1, 32, 32, 32]           9,216
#        BatchNorm2d-4           [-1, 32, 32, 32]              64
#             Conv2d-5           [-1, 32, 32, 32]           9,216
#        BatchNorm2d-6           [-1, 32, 32, 32]              64
#         BasicBlock-7           [-1, 32, 32, 32]               0
#             Conv2d-8           [-1, 32, 32, 32]           9,216
#        BatchNorm2d-9           [-1, 32, 32, 32]              64
#            Conv2d-10           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-11           [-1, 32, 32, 32]              64
#        BasicBlock-12           [-1, 32, 32, 32]               0
#            Conv2d-13           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-14           [-1, 32, 32, 32]              64
#            Conv2d-15           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-16           [-1, 32, 32, 32]              64
#        BasicBlock-17           [-1, 32, 32, 32]               0
#            Conv2d-18           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-19           [-1, 32, 32, 32]              64
#            Conv2d-20           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-21           [-1, 32, 32, 32]              64
#        BasicBlock-22           [-1, 32, 32, 32]               0
#            Conv2d-23           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-24           [-1, 32, 32, 32]              64
#            Conv2d-25           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-26           [-1, 32, 32, 32]              64
#        BasicBlock-27           [-1, 32, 32, 32]               0
#            Conv2d-28           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-29           [-1, 32, 32, 32]              64
#            Conv2d-30           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-31           [-1, 32, 32, 32]              64
#        BasicBlock-32           [-1, 32, 32, 32]               0
#            Conv2d-33           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-34           [-1, 32, 32, 32]              64
#            Conv2d-35           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-36           [-1, 32, 32, 32]              64
#        BasicBlock-37           [-1, 32, 32, 32]               0
#            Conv2d-38           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-39           [-1, 32, 32, 32]              64
#            Conv2d-40           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-41           [-1, 32, 32, 32]              64
#        BasicBlock-42           [-1, 32, 32, 32]               0
#            Conv2d-43           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-44           [-1, 32, 32, 32]              64
#            Conv2d-45           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-46           [-1, 32, 32, 32]              64
#        BasicBlock-47           [-1, 32, 32, 32]               0
#            Conv2d-48           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-49           [-1, 32, 32, 32]              64
#            Conv2d-50           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-51           [-1, 32, 32, 32]              64
#        BasicBlock-52           [-1, 32, 32, 32]               0
#            Conv2d-53          [-1, 128, 16, 16]          36,864
#       BatchNorm2d-54          [-1, 128, 16, 16]             256
#            Conv2d-55          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-56          [-1, 128, 16, 16]             256
#            Conv2d-57          [-1, 128, 16, 16]          36,864
#       BatchNorm2d-58          [-1, 128, 16, 16]             256
#        BasicBlock-59          [-1, 128, 16, 16]               0
#            Conv2d-60          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-61          [-1, 128, 16, 16]             256
#            Conv2d-62          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-63          [-1, 128, 16, 16]             256
#        BasicBlock-64          [-1, 128, 16, 16]               0
#            Conv2d-65          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-66          [-1, 128, 16, 16]             256
#            Conv2d-67          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-68          [-1, 128, 16, 16]             256
#        BasicBlock-69          [-1, 128, 16, 16]               0
#            Conv2d-70          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-71          [-1, 128, 16, 16]             256
#            Conv2d-72          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-73          [-1, 128, 16, 16]             256
#        BasicBlock-74          [-1, 128, 16, 16]               0
#            Conv2d-75            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-76            [-1, 128, 8, 8]             256
#            Conv2d-77            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-78            [-1, 128, 8, 8]             256
#            Conv2d-79            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-80            [-1, 128, 8, 8]             256
#        BasicBlock-81            [-1, 128, 8, 8]               0
#            Conv2d-82            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-83            [-1, 128, 8, 8]             256
#            Conv2d-84            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-85            [-1, 128, 8, 8]             256
#        BasicBlock-86            [-1, 128, 8, 8]               0
#            Conv2d-87            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-88            [-1, 128, 8, 8]             256
#            Conv2d-89            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-90            [-1, 128, 8, 8]             256
#        BasicBlock-91            [-1, 128, 8, 8]               0
#            Conv2d-92            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-93            [-1, 128, 8, 8]             256
#            Conv2d-94            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-95            [-1, 128, 8, 8]             256
#        BasicBlock-96            [-1, 128, 8, 8]               0
#            Conv2d-97            [-1, 256, 4, 4]         294,912
#       BatchNorm2d-98            [-1, 256, 4, 4]             512
#            Conv2d-99            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-100            [-1, 256, 4, 4]             512
#           Conv2d-101            [-1, 256, 4, 4]         294,912
#      BatchNorm2d-102            [-1, 256, 4, 4]             512
#       BasicBlock-103            [-1, 256, 4, 4]               0
#           Conv2d-104            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-105            [-1, 256, 4, 4]             512
#           Conv2d-106            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-107            [-1, 256, 4, 4]             512
#       BasicBlock-108            [-1, 256, 4, 4]               0
#           Linear-109                   [-1, 10]           2,570
# ================================================================
# Total params: 4,988,586
# Trainable params: 4,988,586
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 20.25
# Params size (MB): 19.03
# Estimated Total Size (MB): 39.29
# ----------------------------------------------------------------

# %% [markdown]
# #4. Training and Validation

# %%
# accuracy is the fraction of predictions the model got correct
def calculate_accuracy(y_pred, y):
    top_pred = y_pred.argmax(1, keepdim = True)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    acc = correct.float() / y.shape[0]
    return acc

# time interval for each epoch
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
def train(model, iterator, optimizer, criterion, device):
    
    # Tracks training loss and accuracy as model trains
    epoch_loss = 0
    epoch_acc = 0
    #lrs = []

    # Prep model for training
    model.train()

    for (x, y) in iterator:
        # Move inputs and labels to device
        x = x.to(device)
        y = y.to(device)
        
        # Clear the gradients of all optimized variables
        optimizer.zero_grad()

        # Forward pass: compute predicted outputs by passing inputs to the model        
        y_pred = model(x)
        
        # Calculate the loss
        loss = criterion(y_pred, y)
        
        # Calculate the accuracy
        acc = calculate_accuracy(y_pred, y)
        
        # Backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()

        #OneCycleLr Scheduler
        #scheduler.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def evaluate(model, iterator, criterion, device):
    # Keeps track of validation loss and  accuracy
    epoch_loss = 0
    epoch_acc = 0
    
    # Prep model for evaluation
    model.eval()
    
    with torch.no_grad():
        
        for (x, y) in iterator:

            x = x.to(device)
            y = y.to(device)

            # Forward Pass
            y_pred = model(x)
            # Calculate the validation loss
            loss = criterion(y_pred, y)
            #Calculate the validation accuracy
            acc = calculate_accuracy(y_pred, y)

            #Record validation loss
            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
# Train and Validate the model:

# Tracks average training loss and accuracy per epoch
#  and tracks average validation loss and accuracy per epoch
Train_Loss = []
Train_Acc = []
Val_Loss = []
Val_Acc = []


# Tracks best validation loss
best_valid_loss = float('inf')
for epoch in range(EPOCHS):
    # Epoch start time
    start_time = time.monotonic()


    train_loss, train_acc = train(model, train_dataloader, optimizer, criterion, device)
    valid_loss, valid_acc = evaluate(model, valid_dataloader, criterion, device)
  

    # OnReducePlateau is a scheduler monitoring validation loss
    scheduler.step(valid_loss)

    # Saves model with best validation loss in a state dictionary
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(),'Model_3.pt')
    # Epoch end time
    end_time = time.monotonic()

    # Prints training/validation statistics as well as epoch time
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    print(f'Epoch: {epoch+1:02} || EpochTime: {epoch_mins}m{epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} || Train Acc: {train_acc*100:.2f}%')
    print(f'\t Val Loss: {valid_loss:.3f} ||  Val Acc: {valid_acc*100:.2f}%')

    Train_Loss.append(train_loss)
    Train_Acc.append(train_acc)
    Val_Loss.append(valid_loss)
    Val_Acc.append(valid_acc)
# Out:
# Epoch: 01 || EpochTime: 0m21s
# 	Train Loss: 1.792 || Train Acc: 34.00%
# 	 Val Loss: 1.342 ||  Val Acc: 51.09%
# Epoch: 02 || EpochTime: 0m21s
# 	Train Loss: 1.297 || Train Acc: 53.45%
# 	 Val Loss: 0.920 ||  Val Acc: 67.74%
# Epoch: 03 || EpochTime: 0m21s
# 	Train Loss: 1.072 || Train Acc: 61.93%
# 	 Val Loss: 0.792 ||  Val Acc: 72.77%
# Epoch: 04 || EpochTime: 0m21s
# 	Train Loss: 0.936 || Train Acc: 66.99%
# 	 Val Loss: 0.678 ||  Val Acc: 76.05%
# Epoch: 05 || EpochTime: 0m20s
# 	Train Loss: 0.838 || Train Acc: 70.72%
# 	 Val Loss: 0.639 ||  Val Acc: 77.99%
# Epoch: 06 || EpochTime: 0m20s
# 	Train Loss: 0.774 || Train Acc: 73.15%
# 	 Val Loss: 0.570 ||  Val Acc: 80.10%
# Epoch: 07 || EpochTime: 0m20s
# 	Train Loss: 0.716 || Train Acc: 75.00%
# 	 Val Loss: 0.541 ||  Val Acc: 81.29%
# Epoch: 08 || EpochTime: 0m20s
# 	Train Loss: 0.665 || Train Acc: 76.93%
# 	 Val Loss: 0.602 ||  Val Acc: 80.06%
# Epoch: 09 || EpochTime: 0m20s
# 	Train Loss: 0.634 || Train Acc: 77.89%
# 	 Val Loss: 0.455 ||  Val Acc: 84.38%
# Epoch: 10 || EpochTime: 0m20s
# 	Train Loss: 0.595 || Train Acc: 79.27%
# 	 Val Loss: 0.432 ||  Val Acc: 85.60%
# Epoch: 11 || EpochTime: 0m21s
# 	Train Loss: 0.571 || Train Acc: 80.14%
# 	 Val Loss: 0.457 ||  Val Acc: 84.59%
# Epoch: 12 || EpochTime: 0m21s
# 	Train Loss: 0.535 || Train Acc: 81.55%
# 	 Val Loss: 0.389 ||  Val Acc: 86.43%
# Epoch: 13 || EpochTime: 0m21s
# 	Train Loss: 0.519 || Train Acc: 82.13%
# 	 Val Loss: 0.390 ||  Val Acc: 86.67%
# Epoch: 14 || EpochTime: 0m21s
# 	Train Loss: 0.498 || Train Acc: 82.58%
# 	 Val Loss: 0.377 ||  Val Acc: 87.62%
# Epoch: 15 || EpochTime: 0m20s
# 	Train Loss: 0.477 || Train Acc: 83.32%
# 	 Val Loss: 0.379 ||  Val Acc: 87.50%
# Epoch: 16 || EpochTime: 0m21s
# 	Train Loss: 0.457 || Train Acc: 84.15%
# 	 Val Loss: 0.382 ||  Val Acc: 87.66%
# Epoch: 17 || EpochTime: 0m21s
# 	Train Loss: 0.446 || Train Acc: 84.34%
# 	 Val Loss: 0.349 ||  Val Acc: 88.09%
# Epoch: 18 || EpochTime: 0m20s
# 	Train Loss: 0.428 || Train Acc: 85.04%
# 	 Val Loss: 0.370 ||  Val Acc: 87.88%
# Epoch: 19 || EpochTime: 0m20s
# 	Train Loss: 0.408 || Train Acc: 85.74%
# 	 Val Loss: 0.343 ||  Val Acc: 88.63%
# Epoch: 20 || EpochTime: 0m20s
# 	Train Loss: 0.393 || Train Acc: 86.28%
# 	 Val Loss: 0.321 ||  Val Acc: 89.56%
# Epoch: 21 || EpochTime: 0m21s
# 	Train Loss: 0.381 || Train Acc: 86.97%
# 	 Val Loss: 0.330 ||  Val Acc: 89.28%
# Epoch: 22 || EpochTime: 0m20s
# 	Train Loss: 0.370 || Train Acc: 87.08%
# 	 Val Loss: 0.306 ||  Val Acc: 89.93%
# Epoch: 23 || EpochTime: 0m20s
# 	Train Loss: 0.371 || Train Acc: 87.16%
# 	 Val Loss: 0.303 ||  Val Acc: 89.81%
# Epoch: 24 || EpochTime: 0m21s
# 	Train Loss: 0.346 || Train Acc: 87.85%
# 	 Val Loss: 0.310 ||  Val Acc: 90.15%
# Epoch: 25 || EpochTime: 0m21s
# 	Train Loss: 0.341 || Train Acc: 88.15%
# 	 Val Loss: 0.341 ||  Val Acc: 89.04%
# Epoch: 26 || EpochTime: 0m20s
# 	Train Loss: 0.331 || Train Acc: 88.45%
# 	 Val Loss: 0.282 ||  Val Acc: 90.57%
# Epoch: 27 || EpochTime: 0m21s
# 	Train Loss: 0.322 || Train Acc: 88.77%
# 	 Val Loss: 0.310 ||  Val Acc: 89.77%
# Epoch: 28 || EpochTime: 0m21s
# 	Train Loss: 0.323 || Train Acc: 88.79%
# 	 Val Loss: 0.288 ||  Val Acc: 90.94%
# Epoch: 29 || EpochTime: 0m20s
# 	Train Loss: 0.310 || Train Acc: 89.03%
# 	 Val Loss: 0.286 ||  Val Acc: 91.04%
# Epoch: 30 || EpochTime: 0m21s
# 	Train Loss: 0.302 || Train Acc: 89.49%
# 	 Val Loss: 0.290 ||  Val Acc: 90.70%
# Epoch: 31 || EpochTime: 0m21s
# 	Train Loss: 0.298 || Train Acc: 89.58%
# 	 Val Loss: 0.289 ||  Val Acc: 90.35%
# Epoch: 32 || EpochTime: 0m21s
# 	Train Loss: 0.288 || Train Acc: 89.97%
# 	 Val Loss: 0.267 ||  Val Acc: 91.24%
# Epoch: 33 || EpochTime: 0m21s
# 	Train Loss: 0.286 || Train Acc: 89.90%
# 	 Val Loss: 0.279 ||  Val Acc: 90.92%
# Epoch: 34 || EpochTime: 0m20s
# 	Train Loss: 0.273 || Train Acc: 90.45%
# 	 Val Loss: 0.314 ||  Val Acc: 90.27%
# Epoch: 35 || EpochTime: 0m20s
# 	Train Loss: 0.270 || Train Acc: 90.54%
# 	 Val Loss: 0.288 ||  Val Acc: 90.66%
# Epoch: 36 || EpochTime: 0m20s
# 	Train Loss: 0.258 || Train Acc: 91.03%
# 	 Val Loss: 0.285 ||  Val Acc: 91.40%
# Epoch: 37 || EpochTime: 0m21s
# 	Train Loss: 0.253 || Train Acc: 91.33%
# 	 Val Loss: 0.281 ||  Val Acc: 91.42%
# Epoch: 38 || EpochTime: 0m21s
# 	Train Loss: 0.258 || Train Acc: 91.08%
# 	 Val Loss: 0.273 ||  Val Acc: 91.18%
# Epoch: 39 || EpochTime: 0m21s
# 	Train Loss: 0.250 || Train Acc: 91.28%
# 	 Val Loss: 0.286 ||  Val Acc: 90.94%
# Epoch: 40 || EpochTime: 0m21s
# 	Train Loss: 0.242 || Train Acc: 91.45%
# 	 Val Loss: 0.267 ||  Val Acc: 91.79%
# Epoch: 41 || EpochTime: 0m21s
# 	Train Loss: 0.239 || Train Acc: 91.69%
# 	 Val Loss: 0.285 ||  Val Acc: 91.52%
# Epoch: 42 || EpochTime: 0m20s
# 	Train Loss: 0.236 || Train Acc: 91.92%
# 	 Val Loss: 0.252 ||  Val Acc: 92.37%
# Epoch: 43 || EpochTime: 0m21s
# 	Train Loss: 0.231 || Train Acc: 91.87%
# 	 Val Loss: 0.287 ||  Val Acc: 91.16%
# Epoch: 44 || EpochTime: 0m21s
# 	Train Loss: 0.226 || Train Acc: 92.09%
# 	 Val Loss: 0.264 ||  Val Acc: 91.46%
# Epoch: 45 || EpochTime: 0m20s
# 	Train Loss: 0.226 || Train Acc: 92.03%
# 	 Val Loss: 0.259 ||  Val Acc: 92.37%
# Epoch: 46 || EpochTime: 0m21s
# 	Train Loss: 0.216 || Train Acc: 92.41%
# 	 Val Loss: 0.249 ||  Val Acc: 91.97%
# Epoch: 47 || EpochTime: 0m21s
# 	Train Loss: 0.213 || Train Acc: 92.60%
# 	 Val Loss: 0.294 ||  Val Acc: 91.77%
# Epoch: 48 || EpochTime: 0m21s
# 	Train Loss: 0.219 || Train Acc: 92.46%
# 	 Val Loss: 0.265 ||  Val Acc: 92.29%
# Epoch: 49 || EpochTime: 0m21s
# 	Train Loss: 0.210 || Train Acc: 92.65%
# 	 Val Loss: 0.252 ||  Val Acc: 92.23%
# Epoch: 50 || EpochTime: 0m21s
# 	Train Loss: 0.211 || Train Acc: 92.68%
# 	 Val Loss: 0.246 ||  Val Acc: 92.56%
# Epoch: 51 || EpochTime: 0m21s
# 	Train Loss: 0.206 || Train Acc: 92.90%
# 	 Val Loss: 0.257 ||  Val Acc: 92.17%
# Epoch: 52 || EpochTime: 0m20s
# 	Train Loss: 0.202 || Train Acc: 92.95%
# 	 Val Loss: 0.265 ||  Val Acc: 92.03%
# Epoch: 53 || EpochTime: 0m21s
# 	Train Loss: 0.198 || Train Acc: 93.11%
# 	 Val Loss: 0.257 ||  Val Acc: 92.72%
# Epoch: 54 || EpochTime: 0m21s
# 	Train Loss: 0.197 || Train Acc: 93.19%
# 	 Val Loss: 0.287 ||  Val Acc: 91.97%
# Epoch: 55 || EpochTime: 0m21s
# 	Train Loss: 0.196 || Train Acc: 93.18%
# 	 Val Loss: 0.256 ||  Val Acc: 92.29%
# Epoch: 56 || EpochTime: 0m21s
# 	Train Loss: 0.196 || Train Acc: 93.33%
# 	 Val Loss: 0.280 ||  Val Acc: 92.17%
# Epoch: 57 || EpochTime: 0m21s
# 	Train Loss: 0.184 || Train Acc: 93.69%
# 	 Val Loss: 0.263 ||  Val Acc: 92.29%
# Epoch: 58 || EpochTime: 0m21s
# 	Train Loss: 0.189 || Train Acc: 93.46%
# 	 Val Loss: 0.292 ||  Val Acc: 91.83%
# Epoch: 59 || EpochTime: 0m21s
# 	Train Loss: 0.188 || Train Acc: 93.43%
# 	 Val Loss: 0.273 ||  Val Acc: 92.23%
# Epoch: 60 || EpochTime: 0m20s
# 	Train Loss: 0.181 || Train Acc: 93.76%
# 	 Val Loss: 0.269 ||  Val Acc: 92.15%
# Epoch: 61 || EpochTime: 0m21s
# 	Train Loss: 0.180 || Train Acc: 93.83%
# 	 Val Loss: 0.258 ||  Val Acc: 93.06%
# Epoch: 62 || EpochTime: 0m21s
# 	Train Loss: 0.153 || Train Acc: 94.77%
# 	 Val Loss: 0.218 ||  Val Acc: 93.91%
# Epoch: 63 || EpochTime: 0m21s
# 	Train Loss: 0.136 || Train Acc: 95.39%
# 	 Val Loss: 0.218 ||  Val Acc: 93.97%
# Epoch: 64 || EpochTime: 0m21s
# 	Train Loss: 0.130 || Train Acc: 95.57%
# 	 Val Loss: 0.216 ||  Val Acc: 93.95%
# Epoch: 65 || EpochTime: 0m20s
# 	Train Loss: 0.129 || Train Acc: 95.53%
# 	 Val Loss: 0.222 ||  Val Acc: 93.83%
# Epoch: 66 || EpochTime: 0m21s
# 	Train Loss: 0.128 || Train Acc: 95.57%
# 	 Val Loss: 0.224 ||  Val Acc: 94.07%
# Epoch: 67 || EpochTime: 0m21s
# 	Train Loss: 0.124 || Train Acc: 95.80%
# 	 Val Loss: 0.217 ||  Val Acc: 93.99%
# Epoch: 68 || EpochTime: 0m21s
# 	Train Loss: 0.120 || Train Acc: 95.90%
# 	 Val Loss: 0.222 ||  Val Acc: 93.93%
# Epoch: 69 || EpochTime: 0m21s
# 	Train Loss: 0.119 || Train Acc: 95.83%
# 	 Val Loss: 0.233 ||  Val Acc: 94.05%
# Epoch: 70 || EpochTime: 0m21s
# 	Train Loss: 0.117 || Train Acc: 95.97%
# 	 Val Loss: 0.216 ||  Val Acc: 94.01%
# Epoch: 71 || EpochTime: 0m21s
# 	Train Loss: 0.115 || Train Acc: 96.11%
# 	 Val Loss: 0.221 ||  Val Acc: 94.22%
# Epoch: 72 || EpochTime: 0m20s
# 	Train Loss: 0.116 || Train Acc: 95.98%
# 	 Val Loss: 0.212 ||  Val Acc: 94.05%
# Epoch: 73 || EpochTime: 0m21s
# 	Train Loss: 0.114 || Train Acc: 96.15%
# 	 Val Loss: 0.212 ||  Val Acc: 94.13%
# Epoch: 74 || EpochTime: 0m20s
# 	Train Loss: 0.114 || Train Acc: 96.05%
# 	 Val Loss: 0.220 ||  Val Acc: 94.01%
# Epoch: 75 || EpochTime: 0m21s
# 	Train Loss: 0.110 || Train Acc: 96.22%
# 	 Val Loss: 0.219 ||  Val Acc: 94.11%
# Epoch: 76 || EpochTime: 0m21s
# 	Train Loss: 0.110 || Train Acc: 96.22%
# 	 Val Loss: 0.217 ||  Val Acc: 94.22%
# Epoch: 77 || EpochTime: 0m20s
# 	Train Loss: 0.108 || Train Acc: 96.31%
# 	 Val Loss: 0.224 ||  Val Acc: 94.30%
# Epoch: 78 || EpochTime: 0m21s
# 	Train Loss: 0.110 || Train Acc: 96.23%
# 	 Val Loss: 0.223 ||  Val Acc: 94.19%
# Epoch: 79 || EpochTime: 0m21s
# 	Train Loss: 0.108 || Train Acc: 96.29%
# 	 Val Loss: 0.216 ||  Val Acc: 94.34%
# Epoch: 80 || EpochTime: 0m21s
# 	Train Loss: 0.109 || Train Acc: 96.20%
# 	 Val Loss: 0.225 ||  Val Acc: 94.24%
# Epoch: 81 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.50%
# 	 Val Loss: 0.224 ||  Val Acc: 94.30%
# Epoch: 82 || EpochTime: 0m20s
# 	Train Loss: 0.106 || Train Acc: 96.38%
# 	 Val Loss: 0.222 ||  Val Acc: 94.52%
# Epoch: 83 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.49%
# 	 Val Loss: 0.231 ||  Val Acc: 94.11%
# Epoch: 84 || EpochTime: 0m20s
# 	Train Loss: 0.104 || Train Acc: 96.50%
# 	 Val Loss: 0.226 ||  Val Acc: 94.32%
# Epoch: 85 || EpochTime: 0m21s
# 	Train Loss: 0.098 || Train Acc: 96.63%
# 	 Val Loss: 0.226 ||  Val Acc: 94.56%
# Epoch: 86 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.49%
# 	 Val Loss: 0.224 ||  Val Acc: 94.40%
# Epoch: 87 || EpochTime: 0m21s
# 	Train Loss: 0.098 || Train Acc: 96.63%
# 	 Val Loss: 0.225 ||  Val Acc: 94.32%
# Epoch: 88 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.44%
# 	 Val Loss: 0.222 ||  Val Acc: 94.20%
# Epoch: 89 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.45%
# 	 Val Loss: 0.227 ||  Val Acc: 94.22%
# Epoch: 90 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.45%
# 	 Val Loss: 0.224 ||  Val Acc: 94.34%
# Epoch: 91 || EpochTime: 0m21s
# 	Train Loss: 0.104 || Train Acc: 96.38%
# 	 Val Loss: 0.223 ||  Val Acc: 94.20%
# Epoch: 92 || EpochTime: 0m21s
# 	Train Loss: 0.106 || Train Acc: 96.45%
# 	 Val Loss: 0.223 ||  Val Acc: 94.44%
# Epoch: 93 || EpochTime: 0m21s
# 	Train Loss: 0.105 || Train Acc: 96.42%
# 	 Val Loss: 0.226 ||  Val Acc: 94.46%
# Epoch: 94 || EpochTime: 0m21s
# 	Train Loss: 0.104 || Train Acc: 96.42%
# 	 Val Loss: 0.226 ||  Val Acc: 94.48%
# Epoch: 95 || EpochTime: 0m21s
# 	Train Loss: 0.105 || Train Acc: 96.45%
# 	 Val Loss: 0.221 ||  Val Acc: 94.48%
# Epoch: 96 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.43%
# 	 Val Loss: 0.220 ||  Val Acc: 94.34%
# Epoch: 97 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.47%
# 	 Val Loss: 0.221 ||  Val Acc: 94.42%
# Epoch: 98 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.57%
# 	 Val Loss: 0.224 ||  Val Acc: 94.54%
# Epoch: 99 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.53%
# 	 Val Loss: 0.223 ||  Val Acc: 94.50%
# Epoch: 100 || EpochTime: 0m21s
# 	Train Loss: 0.104 || Train Acc: 96.43%
# 	 Val Loss: 0.222 ||  Val Acc: 94.40%
# Epoch: 101 || EpochTime: 0m21s
# 	Train Loss: 0.099 || Train Acc: 96.57%
# 	 Val Loss: 0.221 ||  Val Acc: 94.58%
# Epoch: 102 || EpochTime: 0m20s
# 	Train Loss: 0.102 || Train Acc: 96.51%
# 	 Val Loss: 0.225 ||  Val Acc: 94.34%
# Epoch: 103 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.55%
# 	 Val Loss: 0.221 ||  Val Acc: 94.34%
# Epoch: 104 || EpochTime: 0m21s
# 	Train Loss: 0.106 || Train Acc: 96.30%
# 	 Val Loss: 0.223 ||  Val Acc: 94.40%
# Epoch: 105 || EpochTime: 0m21s
# 	Train Loss: 0.105 || Train Acc: 96.52%
# 	 Val Loss: 0.224 ||  Val Acc: 94.38%
# Epoch: 106 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.48%
# 	 Val Loss: 0.222 ||  Val Acc: 94.54%
# Epoch: 107 || EpochTime: 0m21s
# 	Train Loss: 0.099 || Train Acc: 96.60%
# 	 Val Loss: 0.226 ||  Val Acc: 94.36%
# Epoch: 108 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.49%
# 	 Val Loss: 0.219 ||  Val Acc: 94.36%
# Epoch: 109 || EpochTime: 0m21s
# 	Train Loss: 0.104 || Train Acc: 96.40%
# 	 Val Loss: 0.222 ||  Val Acc: 94.38%
# Epoch: 110 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.44%
# 	 Val Loss: 0.223 ||  Val Acc: 94.50%
# Epoch: 111 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.45%
# 	 Val Loss: 0.218 ||  Val Acc: 94.46%
# Epoch: 112 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.54%
# 	 Val Loss: 0.225 ||  Val Acc: 94.42%
# Epoch: 113 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.60%
# 	 Val Loss: 0.221 ||  Val Acc: 94.48%
# Epoch: 114 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.55%
# 	 Val Loss: 0.220 ||  Val Acc: 94.42%
# Epoch: 115 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.50%
# 	 Val Loss: 0.219 ||  Val Acc: 94.56%
# Epoch: 116 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.56%
# 	 Val Loss: 0.221 ||  Val Acc: 94.44%
# Epoch: 117 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.56%
# 	 Val Loss: 0.221 ||  Val Acc: 94.30%
# Epoch: 118 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.46%
# 	 Val Loss: 0.220 ||  Val Acc: 94.32%
# Epoch: 119 || EpochTime: 0m21s
# 	Train Loss: 0.097 || Train Acc: 96.69%
# 	 Val Loss: 0.224 ||  Val Acc: 94.32%
# Epoch: 120 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.52%
# 	 Val Loss: 0.223 ||  Val Acc: 94.48%
# Epoch: 121 || EpochTime: 0m20s
# 	Train Loss: 0.101 || Train Acc: 96.55%
# 	 Val Loss: 0.223 ||  Val Acc: 94.48%
# Epoch: 122 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.51%
# 	 Val Loss: 0.227 ||  Val Acc: 94.38%
# Epoch: 123 || EpochTime: 0m21s
# 	Train Loss: 0.099 || Train Acc: 96.61%
# 	 Val Loss: 0.221 ||  Val Acc: 94.40%
# Epoch: 124 || EpochTime: 0m21s
# 	Train Loss: 0.098 || Train Acc: 96.62%
# 	 Val Loss: 0.219 ||  Val Acc: 94.32%
# Epoch: 125 || EpochTime: 0m21s
# 	Train Loss: 0.098 || Train Acc: 96.62%
# 	 Val Loss: 0.218 ||  Val Acc: 94.52%
# Epoch: 126 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.49%
# 	 Val Loss: 0.223 ||  Val Acc: 94.38%
# Epoch: 127 || EpochTime: 0m21s
# 	Train Loss: 0.099 || Train Acc: 96.67%
# 	 Val Loss: 0.223 ||  Val Acc: 94.42%
# Epoch: 128 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.47%
# 	 Val Loss: 0.224 ||  Val Acc: 94.28%
# Epoch: 129 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.54%
# 	 Val Loss: 0.218 ||  Val Acc: 94.22%
# Epoch: 130 || EpochTime: 0m21s
# 	Train Loss: 0.106 || Train Acc: 96.41%
# 	 Val Loss: 0.223 ||  Val Acc: 94.46%
# Epoch: 131 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.49%
# 	 Val Loss: 0.225 ||  Val Acc: 94.54%
# Epoch: 132 || EpochTime: 0m21s
# 	Train Loss: 0.098 || Train Acc: 96.65%
# 	 Val Loss: 0.223 ||  Val Acc: 94.38%
# Epoch: 133 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.59%
# 	 Val Loss: 0.226 ||  Val Acc: 94.40%
# Epoch: 134 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.48%
# 	 Val Loss: 0.221 ||  Val Acc: 94.44%
# Epoch: 135 || EpochTime: 0m21s
# 	Train Loss: 0.101 || Train Acc: 96.58%
# 	 Val Loss: 0.219 ||  Val Acc: 94.46%
# Epoch: 136 || EpochTime: 0m20s
# 	Train Loss: 0.101 || Train Acc: 96.51%
# 	 Val Loss: 0.222 ||  Val Acc: 94.44%
# Epoch: 137 || EpochTime: 0m21s
# 	Train Loss: 0.097 || Train Acc: 96.70%
# 	 Val Loss: 0.222 ||  Val Acc: 94.52%
# Epoch: 138 || EpochTime: 0m21s
# 	Train Loss: 0.097 || Train Acc: 96.74%
# 	 Val Loss: 0.223 ||  Val Acc: 94.42%
# Epoch: 139 || EpochTime: 0m21s
# 	Train Loss: 0.104 || Train Acc: 96.39%
# 	 Val Loss: 0.227 ||  Val Acc: 94.24%
# Epoch: 140 || EpochTime: 0m21s
# 	Train Loss: 0.099 || Train Acc: 96.57%
# 	 Val Loss: 0.222 ||  Val Acc: 94.42%
# Epoch: 141 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.50%
# 	 Val Loss: 0.224 ||  Val Acc: 94.32%
# Epoch: 142 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.50%
# 	 Val Loss: 0.220 ||  Val Acc: 94.42%
# Epoch: 143 || EpochTime: 0m21s
# 	Train Loss: 0.097 || Train Acc: 96.63%
# 	 Val Loss: 0.217 ||  Val Acc: 94.38%
# Epoch: 144 || EpochTime: 0m21s
# 	Train Loss: 0.102 || Train Acc: 96.54%
# 	 Val Loss: 0.224 ||  Val Acc: 94.38%
# Epoch: 145 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.42%
# 	 Val Loss: 0.224 ||  Val Acc: 94.60%
# Epoch: 146 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.59%
# 	 Val Loss: 0.223 ||  Val Acc: 94.36%
# Epoch: 147 || EpochTime: 0m21s
# 	Train Loss: 0.104 || Train Acc: 96.37%
# 	 Val Loss: 0.223 ||  Val Acc: 94.46%
# Epoch: 148 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.66%
# 	 Val Loss: 0.218 ||  Val Acc: 94.50%
# Epoch: 149 || EpochTime: 0m21s
# 	Train Loss: 0.100 || Train Acc: 96.55%
# 	 Val Loss: 0.222 ||  Val Acc: 94.42%
# Epoch: 150 || EpochTime: 0m21s
# 	Train Loss: 0.103 || Train Acc: 96.48%
# 	 Val Loss: 0.223 ||  Val Acc: 94.34%

# %%
# visualize the loss as the network trained
def get_loss_plot(train_loss, val_loss):
    plt.plot(range(len(train_loss)),train_loss)
    plt.plot(range(len(train_loss)),val_loss)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.title('Loss')
    plt.legend(['Training Loss', 'Validation Loss'])
    plt.savefig('Model_3.png')
    plt.show()
    
    
# Prints training loss and validation loss 
get_loss_plot(Train_Loss, Val_Loss)

# %% [markdown]
# #5.  Evaluate Best Saved Model on Test Dataset

# %%
# Load saved model's parameters
model.load_state_dict(torch.load('Model_3.pt'))

# Calculate test loss and accuracy
test_loss, test_acc = evaluate(model, test_dataloader, criterion, device)


print(f'Test Loss: {test_loss:.3f} || Test Acc: {test_acc*100:.2f}%')
# Out:
# Test Loss: 0.218 || Test Acc: 94.10%
